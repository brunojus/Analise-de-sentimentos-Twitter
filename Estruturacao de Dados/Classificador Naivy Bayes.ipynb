# %%
from textblob import TextBlob
import pandas as pd  
import numpy as np
from textblob.classifiers import NaiveBayesClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords

# %%
dilma1turno=pd.read_csv("DadoFinal_Dilma1turno.txt",delimiter="\t",encoding='latin-1')
dilma2turno=pd.read_csv("Dados Treinamento/clasdilma2.txt",delimiter="\t",encoding='latin-1')

# %%
aecio1turno=pd.read_csv("Dados Treinamento/clasAecio1.txt",delimiter="\t",encoding='latin-1')
aecio2turno=pd.read_csv("Dados Treinamento/clasAecio2.txt",delimiter="\t",encoding='latin-1')

# %%
subset = dilma1turno[['text', 'sentiment']]
tuples_dilma_1turno = [tuple(x) for x in subset.values]

# %%
subset = dilma2turno[['text', 'sentiment']]
tuples_dilma_2turno = [tuple(x) for x in subset.values]

# %%
subset = aecio1turno[['text', 'sentiment']]
tuples_aecio_1turno = [tuple(x) for x in subset.values]

# %%
subset = aecio2turno[['text', 'sentiment']]
tuples_aecio_2turno = [tuple(x) for x in subset.values]

# %%
tuples_dilma_1turno_train = tuples_dilma_1turno[15000:]
tuples_dilma_1turno_test = tuples_dilma_1turno[:15000]

# %%
# Out:
# [('geraldo alckmin reeleito governador sao paulo ja ta decidido dilma vai pro segundo turno contra aecio neves aeciodevirada',
#   'negativo'),
#  (' turno dilma aecio dois bosta', 'negativo'),
#  ('dilma rousseff  pt  aecio neves  psdb  vao disputar  turno', 'neutro'),
#  ('dilma novo nao ne', 'neutro'),
#  ('vai ser tao apertado votos luciana genro podem eleger dilma sim',
#   'positivo'),
#  ('voces idolatrando aecio  minimo  nao sabem nada sobre governo so vao status odiar dilma  parabens galera',
#   'negativo'),
#  ('segundo turno treva      urnas apuradas dilma votos aecio neves    marina   ',
#   'neutro'),
#  ('dilma aecio af', 'negativo'),
#  ('pobreso pensa bolsa familia so q dilma sabe oferecertrouxas tudo voto p causa reais ',
#   'negativo'),
#  ('coisa nordestino votar dilma so causa bolsa familia mentira  aqui trabalhador gentr q acorda cedo pra trabalha',
#   'positivo'),
#  ('turno dilma aecio neves ', 'neutro'),
#  ('aecio ta so   atras dilma  vamos virar brasil    pictwitterhkplxnfclv',
#   'neutro'),
#  ('falei ia dar aecio cheira po dilma segundo turno falei falei ', 'neutro'),
#  ('unica coisa n queria alckmin governador  dilma aceito', 'neutro'),
#  ('affs povo mete pau dilma agora vai la vota nela merda', 'negativo'),
#  ('aaaargh odio desse povo brasileiro  faz protesto   faz caralho quatro pra chegar hoje votar dilma ',
#   'negativo'),
#  ('confirmado aecio neves x dilma segundo turno  neles ', 'positivo'),
#  ('dilma ganhou causa pobres ', 'negativo'),
#  (' turno confirmado    dilma x aecio', 'positivo'),
#  ('dilma perde segundo turno', 'negativo'),
#  ('aecio dilma segundo turno  aecioconfirma', 'positivo'),
#  ('toma porra to revoltada pais retardado q vota dilma meoooo', 'negativo'),
#  ('antigamente so filhos ricos formavam  gracas dilma vejo filhos empregadas domestica universidade  formei gracas pt ',
#   'positivo'),
#  ('dilma dilma dilma', 'neutro'),
#  ('  dilma pegou pais ja estabilizado sistema pt   anos ja pt  facil assim nao ',
#   'positivo'),
#  ('tanto faz aecio dilma nenhum ai prestar msm', 'neutro'),
#  ('partiu segundo turno    dilma vs aecio    ', 'neutro'),
#  ('dilma aecio estao garantidos segundo turno    chavalzada', 'negativo'),
#  ('0 turno aecio dilma puts', 'neutro'),
#  (' verdade vamos ver marina outros vao apoiar dilma atacou marina vamos ver agora ne',
#   'neutro'),
#  ('debate aecio dilma turno sera covardia dilma nao tera chance', 'positivo'),
#  ('dilma aecio segundo turno voces sao otarios', 'neutro'),
#  ('nao favor dilma   aecio  pra mim devia ser presidente ', 'neutro'),
#  ('confirmado dilma aecio pro segundo turno dilma querida  deixa procurar voto pra voce',
#   'positivo'),
#  ('culpa nao dilma vc trouxa ir la protesto falar mal dps votar mesma',
#   'negativo'),
#  ('segundo turno confirmado  dilma aecio', 'positivo'),
#  (' mae mae petista feio ta querendo cumer mae  bua bua so fiinho di papai maie  bua bua dilma feia vai ganhar di novo bua bua',
#   'negativo'),
#  (' turno confirmado dilma rousseff aecio neves vou blog dilma rousseff novo ',
#   'positivo'),
#  ('dilma x aecio  ', 'neutro'),
#  ('falou vai votar dilma   ancia d vomito', 'neutro'),
#  (' acredito q eleitores marina tb vao pra dilma   sei la ne', 'positivo'),
#  ('dilma aecio neves disputarao segundo turno diferenca votos sam', 'neutro'),
#  ('mae ta enchendo saco causa dilma scrr', 'neutro'),
#  ('presidencia brasil sera decidida segundo turno dilma rousseff aecio neves',
#   'negativo'),
#  ('n consigo entender pq brasil inteiro moveu pra tentar mudar situacao  pra mudar governo  dai dps votam dilma   tipo    ',
#   'positivo'),
#  ('segundo turno aecio dilma   manero  n sei rio  choro', 'positivo'),
#  ('muda brasil dilma barbudo safado  ', 'neutro'),
#  ('zuerinha odeio dilma gorda', 'negativo'),
#  ('dilma vai ganhar gente  infelizmente', 'positivo'),
#  ('confirmado aecio dilma', 'positivo'),
#  ('oficial  segundo turno dilma aecio', 'neutro'),
#  ('dilma rousseff y aecio neves disputaran segunda vuelta en brasil',
#   'negativo'),
#  (' turno cara dilma', 'neutro'),
#  ('muy buena votacion del democrata neves solo   dilma  supera el    dif  voto obligatorio vuelve muy incierta la  vuelta ',
#   'positivo'),
#  ('dilma rousseff enfrentara aecio neves en segunda vuelta presidencia brasil',
#   'negativo'),
#  ('dilma vs aecio ganha eh dilma genty', 'positivo'),
#  ('recuso ver segundo turno dilma x aecio', 'neutro'),
#  ('visto  infelizmente vou ter votar dilma segundo turno', 'negativo'),
#  ('  ahora es comenzara correr dinero ahi  lograr alianzas dilma    ',
#   'neutro'),
#  (' hrs  dilma ganhar pq roubado   ganhar apoio mega protesto foradilma    likelike   share',
#   'positivo'),
#  ('dilma nao  menos aecio nao  eita povo lerdo ', 'positivo'),
#  ('  aecio   pra dilma sentar', 'negativo'),
#  (' dilma   jair pedro  protesto ja nao ninguem   joao paulo  rene patriota edilson silva',
#   'neutro'),
#  (' tambem nao recebo bolsa familia deixem votar dilma ', 'neutro'),
#  ('dilma aecio segundo turno dilma fudeu kkkkkkkk aecio', 'neutro'),
#  ('minas gerais  onde aecio conhecido  povo deu vitoria dilma so desinformados votam tipo sujeito desse ',
#   'negativo'),
#  ('tirei  redacao pq falei vcs votam dilma  otarios ', 'neutro'),
#  ('voces votaram dilma esperando faca algo bom  vao ficar esperando porque algo nao fez fara',
#   'positivo'),
#  (' vale lembrar  dilma recebeu porcentagem alta votos  turno todos marina  diz algo',
#   'positivo'),
#  ('rt   so dica dilma cair  servidor cai tambem viu  concurso so kakakak',
#   'neutro'),
#  ('deu dilma aecio', 'neutro'),
#  ('dilma   jeito caminhoneira  fez copa  implantou programas pro brasil  respeita vinhado  br heuehuehe dilma presidente',
#   'positivo'),
#  ('dilma deve estar cu mao horas', 'neutro'),
#  (' tbm n leq  aecio ganhar acabou pais  esperanca  porra toda dilma fdp melhor deixar dilma',
#   'positivo'),
#  ('prepara brioco dilma  ', 'neutro'),
#  ('vou votar nulo segundo turno  recuso votar dilma aecio', 'neutro'),
#  ('povo pra rua protestar  meteu pau dilma pra hoje ta ai primeiro lugar  povo hipocrita ',
#   'positivo'),
#  (' kkkkkkkkkkkkk pse pessoas sao muts burra q votaram dilma   ', 'negativo'),
#  ('agora oficial dilma aecio confirmados  turno', 'positivo'),
#  ('segundo turno dilma rousseff aecio neves  so aecio  vai aecio ', 'neutro'),
#  ('definido dilma aecio votos vao segundo turno', 'neutro'),
#  ('dilma reeleita  tchau brasil', 'neutro'),
#  ('faltando menos fim apuracoes aecio neves garante briga segundo turno dilma  aecio wins  ',
#   'negativo'),
#  ('votos apurados  confirmado matematicamente segundo turno presidente dilma tucano aecio neves',
#   'positivo'),
#  ('crei la competencia solo estaba dilma y marina  ', 'positivo'),
#  ('ih  margem diferenca dilma aecio ta aumentando', 'positivo'),
#  ('votacaobr  dilma rousseff    aecio neves    marina silva    apurados   eleicoes  tseh ',
#   'neutro'),
#  ('dilma aecio turno vamos vamos aecio', 'neutro'),
#  ('viixii aecio dilma   vai pro segundo turmo kkkk', 'positivo'),
#  ('  alguem conhece alguem algo ganhar eleicao aecio   nao gosto dilma   nao',
#   'neutro'),
#  ('    dilma aecio segundo turno passagem pra marte ai  kkkk', 'negativo'),
#  ('gente dilma ganhar  aecio cu rolaaaaa', 'positivo'),
#  (' turno presidente dilma x aecio', 'neutro'),
#  ('fechou dilma aecio segundo turno', 'negativo'),
#  (' caiu forninho dilma', 'neutro'),
#  ('urnas apuradas  dilma rousseff  pt  aecio neves  psdb  vao disputar segundo turno eleicoes presidenciais',
#   'negativo'),
#  ('kkkk pessoas q defendem dilma merda cabeca real  mulher n fez nada pais amor deus',
#   'positivo'),
#  ('dilma vc falhou', 'negativo'),
#  ('dilma aecio turno  ai cu  dilma nao pode ganhar galero', 'negativo'),
#  ('otarios fazem tudo fim votam dilma pictwitterefejfjt', 'neutro'),
#  ('aecio ganhar ferrou tudo  prefiro x tia dilma ', 'neutro'),
#  ('  tambem  ja viu escolas alguns lugares sao   enfim ta sacanagem votar dilma ',
#   'neutro'),
#  ('perdi dia pastel caldo cana pra ver dilma ganhando  porra', 'positivo'),
#  ('dilma subindo ainda  afazenda', 'positivo'),
#  ('turmo dilma aecio     dalhedilma nessa porrra pra fuder anos  antes dilma aecio ',
#   'positivo'),
#  ('queda livre x ascensao  segundo turno dilma aecio  nao dilma marina pesquisas sao furadas',
#   'positivo'),
#  ('chupaaaa dilma trouxa  aecio vai ganhar uhull', 'positivo'),
#  ('rica ja vazado daqui n vou ter aguentar dilma anos  vida deus', 'positivo'),
#  ('dilma cara porra  vai tomar cu kkkk', 'negativo'),
#  (' dilma ja fez q queria brasil  chega pt', 'neutro'),
#  ('aecio segundo turno dilma   forapt ', 'negativo'),
#  ('engracado povo vota dilma reclama certas situacoes passam ', 'positivo'),
#  ('dilma aecio  turno  olha rapaz  vai ser loco', 'negativo'),
#  ('votem dilma votem dilma convencam todos votarem dilma d i l m ', 'neutro'),
#  ('acho castigo so porque falei nao votava dilma', 'neutro'),
#  ('so vendo tml gente vota citando protestos ano passado pra dilma ',
#   'neutro'),
#  ('dilma caralho  anos fez  porra nenhuma povo ainda voto nela ', 'negativo'),
#  ('importante eh bairro dilma n ganhou pena q n brasil', 'positivo'),
#  ('deve ser pais imaginario dilma pt nao vai ter segundo turno vai ter pra caralho  hahaahaahahaaahahaha',
#   'negativo'),
#  ('  urnas apuradas dilma rousseff    aecio neves    marina silva    luciana genro    pastor everaldo   ',
#   'neutro'),
#  ('ainda falta apurar metade desse nordeste brasileiro vai eleger dilma  sai aecio pra la',
#   'positivo'),
#  ('aecio ganhar  ate marina serve  dilma filha capeta naooooo', 'positivo'),
#  ('  considerando ultima pesquisa ibope  dilma perdeu   disse votaria nela  brappnoticiaes peciaiseleicoes   internapolitica ibope aponta aecio contra ',
#   'neutro'),
#  ('vo discutindo vo causa dilma', 'neutro'),
#  ('aeeeee      aecio vs dilma', 'neutro'),
#  ('ceis ja imaginaram dilma reeleita vingando vaias copa ', 'neutro'),
#  ('turno dilma aecio  aaaah mlk', 'neutro'),
#  ('turno dilma aecio  mete pau nela aecio   ', 'neutro'),
#  ('ehhhhhh dilma      moio      segura agora   ', 'positivo'),
#  ('    turno eleicoes presidenciais definido dilma aecio dilma pra continuar crescendo  ',
#   'neutro'),
#  ('segundo turno dilma aecio meeeeeerrrrrrreddddddaaaaaaa', 'neutro'),
#  ('dilma desgracada', 'neutro'),
#  ('   en un resultado inesperado  dilma y aecio neves van segunda vuelta en brasil pictwitterhenvoebakw  es increible',
#   'positivo'),
#  ('agora oficial dilma ficou apenas     acima aecio nao marina  aecio atual presidente brasil chega pt   ',
#   'neutro'),
#  ('ai gente  nao votava dilma nao fez nada ate agora nao vai fazer proximo governo',
#   'neutro'),
#  (' rj marina bem perto dilma votos  apoiar vai ser bem vindo kkkkk',
#   'positivo'),
#  ('dilma x aecio eita  aecio vc leva porra  foradilma forapt', 'negativo'),
#  ('vota aecio ai vem reclamar governo daqui  anos  assim dilma', 'neutro'),
#  ('ta decidido dilma porra otaria vaca odeio pega aecio segundo turno',
#   'negativo'),
#  ('menino aecio caminhando torar pesca dilma sendo turnors', 'neutro'),
#  ('alerta dilma rousseff y aecio neves van al ballottage en brasil  lnaruqanz',
#   'neutro'),
#  ('olha ai galera kkkkk    dilma ganha norte nordeste falar incentivar preconceito  entao processe',
#   'positivo'),
#  ('aecio dilma segundo turno   votem aeciooooooooooooo', 'neutro'),
#  ('ahhhhhhhhhhhhhhhhhhhh segundo turnooooo    agora venhaaa dilma  dale aecioooooooooooooooooooooooooo   ',
#   'neutro'),
#  ('   foda dilma nao cara tia', 'neutro'),
#  ('nao to acreditando vou ter ter trabalho sair casa pra poder votar dilma aecio',
#   'neutro'),
#  ('sabiaaaa dilma x aecio  pt', 'neutro'),
#  ('segundo turno dilma aecio sinceramente povo brasileiro quer tomar cu msm emabiggestfansd',
#   'positivo'),
#  ('n acredito q vai ter aecio dilma segundo turno cade lulu genro rainha gente',
#   'negativo'),
#  (' governo dilma passou longe perfeito  outros candidatos  poderia ser menos pior nao acha ',
#   'positivo'),
#  ('sei la vcs nao acha estranho dilma  ajudar paises comunistas', 'negativo'),
#  ('resultats dolents del pt tot arreu dilma va guanyar la primera volta amb    ara nomes   brasildecide',
#   'negativo'),
#  ('perguntar  pontos programa governo aecio vcs nao saberao responder pq importa dilma ',
#   'positivo'),
#  ('   urnas apuradas  dilma vai segundo turno aecio neves   pictwitteriunniatq ',
#   'negativo'),
#  ('havera  turno presidente  dilma rousseff obteve    aecio neves    eleicoes',
#   'neutro'),
#  ('aercio ser eleito sim  to cansada anos roubalheira dilma brasileiros burros',
#   'negativo'),
#  ('aecio x dilma', 'negativo'),
#  ('dilma aecio pro turno', 'neutro'),
#  ('tudo pra chegar hoje votarem dilma   pictwitterkkuswkyr', 'neutro'),
#  ('quer saber inferno anti petistas  segundo turno vou dilma', 'negativo'),
#  ('odeio dilma todas letras mano', 'negativo'),
#  ('fijate lo decia el diario clarin argentino  amigo oglobo brasilero brasildecide dilma     silva   pictwitterikdejxsym',
#   'neutro'),
#  ('agora vou ser obrigado votar dilma ', 'positivo'),
#  ('dilma x aecio segundo turno', 'neutro'),
#  ('agora oficial segundo turno dilma aecio agora ve vcs abrem olho votem aecio ja chega burrice',
#   'negativo'),
#  ('turno  dilma x aecio  ', 'neutro'),
#  ('agora duvida firmou dilma x aecio to fodida', 'negativo'),
#  (' culpa mano todas decisoes pais passam chefe poder executivo chamada dilma rousseff',
#   'neutro'),
#  ('votei dilma hoje', 'neutro'),
#  ('dilma rousseff le alcanzaron los votos y debera enfrentarse aecio neves el  octubre eleccionesbrasil  ',
#   'neutro'),
#  ('q vota dilma agr ne pq aecio n daaaaaaahhh', 'neutro'),
#  ('olha aecio chegando olha dilma saindo sera     ', 'neutro'),
#  ('dilma x aecio run to the hills ', 'neutro'),
#  ('aecio ganhar porra  vcs votarem dilma   brasil vai continuar msm  n adianta reclamar',
#   'positivo'),
#  ('gente  aecio dilma nivel  problema agora ver menos pior', 'negativo'),
#  ('antes dilma marina aecio dilma', 'neutro'),
#  ('defindo segundo turno dilma  aecio    uh huuuuuuuuuuuuuu   ', 'neutro'),
#  (' vota aecio miga  tira dilma', 'neutro'),
#  ('    band cientista politico falou so   vai ser distribuido aecio dilma',
#   'neutro'),
#  ('dilma poupou aecio  turno derrubar marina agora  vai enfrentar politico profissional  boa  ',
#   'neutro'),
#  ('cra dilma reeleger ai vamo ta merda d vez   foradilma forapt', 'negativo'),
#  ('segundo turno dilma aecio oficial', 'neutro'),
#  ('aecio dilma mo segundo turno ', 'positivo'),
#  ('dilma aecio ta tudo otimo   imagina marina meio   deus q livre kkk',
#   'positivo'),
#  ('n gosto aecio dilma   faz ', 'neutro'),
#  (' dilma con   aprox', 'neutro'),
#  ('dilma aecio caraca', 'neutro'),
#  ('segundo turno eleicoes presidenciais dilma  pt  x aecio  psdb ',
#   'negativo'),
#  ('pau cu destroi metade brasil justica clica porra maquina numero dilma vao fode',
#   'negativo'),
#  ('dilma aecio segundo turno agora quero ver merda vai dar', 'negativo'),
#  ('menos   dilma  marina euvoteimarina', 'negativo'),
#  ('moral   anos reclamando falando brasil lixo pra chegar hoje votar dentuca dilma',
#   'negativo'),
#  (' burra pessoal acha aecio entrar lugar dilma grande avanco nao deve ser',
#   'positivo'),
#  ('voce acha nao poderia ficar pior dilma aecio segundo turno', 'negativo'),
#  ('vai burro  dilma eleita faco video  preciso externar raiva q desse povo  ',
#   'negativo'),
#  ('resta vai dilma ganha pra mim', 'positivo'),
#  ('segundo turno definido dilma x aecio', 'neutro'),
#  ('entao vamo pro  turno povo  dilma x aecio ', 'neutro'),
#  (' negocio pt tudo birrinha  sabe dilma melhor fica nessa so p ser contra ',
#   'positivo'),
#  ('brasil tera segundo turno dilma aercio', 'negativo'),
#  ('aecio ganhar  pq  qualquer coisa vai ser melhor dilma', 'positivo'),
#  ('matem  anotem dilma vai ganhar agora daqui anos lula ganha tbm dps anos reelege  anos puro pt hmm delicia',
#   'positivo'),
#  ('desde comeco eleicao contra aecio entao voto dilma ate fim', 'neutro'),
#  ('agora oficial segundo turno dilma aecio', 'negativo'),
#  ('brasileiro povo burro dilma indo pro segundo turno ganhando ainda',
#   'negativo'),
#  ('quero fazer csf  nojo  nojo voces votaram dilma so causa ciencia fronteiras',
#   'positivo'),
#  ('agr oficial  dilma aecio segundo turno', 'neutro'),
#  ('dilma aecio kkkkkkkk so rindo ', 'positivo'),
#  ('parabens burros votaram dilma aecio', 'neutro'),
#  (' li gente falando tentou votar aecio apareceu dilma  tao trovando nao existe democracia agora ',
#   'neutro'),
#  ('voce defende dilma  va tomar c  espero q foda vida  ', 'negativo'),
#  ('nao sei eh pior  aecio dilma brasil  excelente candidatos d smp p smp',
#   'positivo'),
#  ('segundo turno  dilma aecio ', 'positivo'),
#  ('aecio dilma  pulso cortar ', 'neutro'),
#  (' pra dilma gosto aecio pena aqui minas nao fez nada', 'positivo'),
#  ('sera dilma aecio segundo turno abre olho  pt ', 'negativo'),
#  (' funkyspyrousseff set to face brazil run off incumbent dilma rousseff has won most votes in brazils pr ',
#   'positivo'),
#  ('segundo turno sera dilma aecio eleicoes  ', 'neutro'),
#  ('lixo aecio dilma turno marina pra ta ai', 'neutro'),
#  ('guria defende dilma dilma desse dinheiro p kkkkkkkk seila ne  vai sabe',
#   'neutro'),
#  ('marina disser apoia dilma   vou rir vida inteira uhahuauhuhauhauhahuauhhuahuauhauhauh xd',
#   'positivo'),
#  ('aecio q ganhar   anos dilma   deus meee livre', 'positivo'),
#  ('aecio q vencer  dilma novo nao', 'positivo'),
#  ('dilma aecio vao disputar segundo turno', 'neutro'),
#  (' la va ganary dilma y el comunismo pasara ser historia en brasil',
#   'positivo'),
#  ('dilma aecio turno eh barraco', 'positivo'),
#  ('dilma vai ganhar povo tudo burro nao serve pra votar', 'positivo'),
#  ('nao sei pior dilma aecio affz ninguem merece ', 'negativo'),
#  ('serio gente  mineira to falando dilma aecio fiquem dilma ', 'negativo'),
#  ('bairro ta soltando fogos dilma estar  turno', 'neutro'),
#  ('dilma aecio segundo turno vou pra russia', 'negativo'),
#  ('dilma novo pra presidente  nao mereco', 'neutro'),
#  ('hm deve estar doendo cu dilma agora apuracao', 'neutro'),
#  (' tao bom minas peso votou dilma', 'positivo'),
#  ('aecio forte esperado neste cenario  provavel dilma perca  turno',
#   'negativo'),
#  ('rede globo fez tanto pessoas odiarem pt dilma ta segundo turno kkkkkkkk',
#   'negativo'),
#  ('dilma nao pode ganhar serio', 'negativo'),
#  ('definido segundo turno dilma x aecio desanima ne  velha polarizacao',
#   'positivo'),
#  ('dilma aecio  lembre melhor diabo voce conhece povo ta achando nao pode piorar',
#   'positivo'),
#  ('prefiro marina aecio tbm  parece ser pior dilma   agr pqp votou dilma q tomar n cu bonito   desculpaaemae  ',
#   'negativo'),
#  ('dilma aecio entao gente votem  amor deus', 'positivo'),
#  ('apurados   votos dilma   aecio   marina   luciana    outros menos ',
#   'negativo'),
#  ('povo mete ferros dilma   faz campanha contra  protestos rua ainda vota nela  brasileiro foder i',
#   'negativo'),
#  ('voto secreto  vou falar coisa votei ninguem presidente  digitei  segundo turno  qualquer menos dilma ',
#   'negativo'),
#  ('sabia dilma estaria frente', 'neutro'),
#  ('quero dizer dilma   tempo esgotou  candidata mudabrasil foradilma brasilsemdilma',
#   'negativo'),
#  ('quero ver segundo turno pegar fogo  aecio dilma   ', 'neutro'),
#  (' votou agora luciana pra apoiar sabia ia ter segundo turno vai votar dilma',
#   'negativo'),
#  (' fracasso  paises chamados baleias sul pq tamo crescendo pra caralho   amo dilma vdd dita',
#   'positivo'),
#  ('deixa dilma anos pra vcs verem vai ta inflacao nao vai ter dinheiro pra comprar balinha foradilma',
#   'positivo'),
#  ('segundo turno acho dilma estrepa', 'negativo'),
#  ('vcs falando dilma permitiu comprar casa amiga permitiu tanto imposto pessoa morre pagando casa carro acordem',
#   'positivo'),
#  ('dilma aecio segundo turno  tipo', 'neutro'),
#  ('dilma aecio segundo turno   correr bicho pega   ficar bicho come',
#   'neutro'),
#  ('dilma    aecio    jesus  ', 'positivo'),
#  ('  brasil   dilma     neves     marina', 'neutro'),
#  ('engracado argumento povo ai vcs ruas ano passado p votar dilma hoje querida presidente nao governa sozinho',
#   'positivo'),
#  ('  diferenca  segundo turno confirmado dilma aecio', 'positivo'),
#  ('oqq cabeca pessoa p votar dilma pezao', 'neutro'),
#  ('pronto  turno confirmado dilma x aecio', 'positivo'),
#  ('dilma x aecio  vamos pro segundo turno', 'neutro'),
#  ('oficial   segundo turno dilma rousseff     aecio neves     quase   urnas apuradas',
#   'neutro'),
#  ('agora q venca aecio   q dilma quatro anos nao vai dar certo  ', 'positivo'),
#  ('votou marina vai votar dilma   votou namelia vai votar sartori   omg ',
#   'neutro'),
#  ('bora comecar campanha pra dilma segundo turno entao', 'negativo'),
#  ('dilma aecio  prefiro ficar presidente   ', 'neutro'),
#  ('norte nordeste dilma minas gerais tambem', 'neutro'),
#  ('rt  dilma vai pedir voto marinista agora ', 'neutro'),
#  ('dilma x aecio todos juntos contra pt', 'neutro'),
#  ('nao acredito marina nao ta segundo turno ainda beleza  desde dilma perca',
#   'neutro'),
#  ('economia brasil ta tao boa dilma sobe pesquisas bovespa fecha baixa  vai la  vota nela',
#   'positivo'),
#  ('dilma rousseff aecio neves definidos  turno vou pensa votar', 'neutro'),
#  ('genteeeee to chaaaaao destruido vai ser aecio dilma ne putos', 'neutro'),
#  ('segundo turno aecio vai caca  chupa dilma   ', 'negativo'),
#  (' dilma   rum', 'neutro'),
#  ('presidencia        apurados  dilma      aecio      marina     ', 'neutro'),
#  ('  aecio nao ganhara dilma muitos pensam', 'positivo'),
#  ('votarei dilma segundo turno', 'negativo'),
#  ('dilma aecio segundo turno  nao sei pior', 'negativo'),
#  ('aecio dilma votos estao segundo turno aecio aeciopresidente euvotoaecionoturno',
#   'negativo'),
#  ('   chega dilma vez todas vamosdeaecio  ', 'neutro'),
#  ('dilma aecio vao disputar segundo turno', 'neutro'),
#  (' la historiatambien decia q la diferencia d dilma con el mayoren defintiva las encuestas son  x  confiables ',
#   'positivo'),
#  ('tudo pra chegar votar dilma  pictwitterzngixfpzg', 'neutro'),
#  ('euvoteimarina infelizmente dilma vence facil  turno', 'positivo'),
#  ('dilma rousseff vai disputar segunda volta aecio neves', 'negativo'),
#  ('aecio dilma tudo mesma merda vamos votar nulo', 'negativo'),
#  (' cruzeiro  ops dilma  qq', 'neutro'),
#  ('segundo turno dilma aecio ainda bem', 'neutro'),
#  ('atencao matematicamente definido  dilma aecio disputarao segundo turno elecoes',
#   'neutro'),
#  ('dilma vote ', 'neutro'),
#  ('acabou  dilma aecio', 'neutro'),
#  ('segundo turno pra presidencia dilma aecio puta pariu dois jeitos gente ta bosta',
#   'negativo'),
#  ('ja deu aecio dilma galerinhaaaaaa', 'neutro'),
#  ('vcs falam tanto aecio professores  dilma faz algo p valorizar servidores publicos ',
#   'positivo'),
#  ('povo fez protesto caralho ano passado  pra ano levar dilma pro segundo turno  puta pariu',
#   'negativo'),
#  ('dilma   aecio   marina   vontade conhecer idolos  ', 'neutro'),
#  (' vai pra segundo turno aecio dilma', 'neutro'),
#  ('  marina manda dilma ir cucuias  turma bando ladroes', 'neutro'),
#  ('povo segundo turno vai dar dilma rollemberg', 'neutro'),
#  ('rt  driver roll up to planalto please ', 'neutro'),
#  ('contar  q governo dilma deixou inflacao completamente abalada ainda age normal',
#   'positivo'),
#  ('segundo turno dilma aecio  ', 'positivo'),
#  ('visto vou ter anular voto pra presidente segundo turno votar dilma aecio  hipocrisia grande rs tenso',
#   'negativo'),
#  ('definido dilma  pt  aecio  psdb  vao disputar segundo turno', 'negativo'),
#  ('    dilma ganhando estado q aecio aprovacao pfv explica q q aconteceu suica brasileira ',
#   'neutro'),
#  ('segundo turno dilma vs aecio', 'neutro'),
#  ('guerra declarada dilma aecio turno', 'neutro'),
#  ('segundo turno dilma x aecio comece peleja eleicoes', 'neutro'),
#  ('acho q  ate bom aecio ganhar  vcs perceberem q dilma n ruim comparado outros   anos p vcs perceberem tudo ',
#   'positivo'),
#  ('aecio dilma segundo turno  olha merda ai', 'negativo'),
#  (' antes nao estaria preocupado  quica tricolor  bucha maximo tricolete anda histerico dilma',
#   'negativo'),
#  ('aecio dilma ficam logo dois piores puta pariu', 'negativo'),
#  ('filha puta aecio ta colado dilma', 'neutro'),
#  ('euvoteimarina tudo menos dilma', 'neutro'),
#  ('tanto dilma aecio neves marina silva comieron siete y pueden ir la concha bien su madre',
#   'neutro'),
#  ('definido  dia   dilma x aecio', 'positivo'),
#  ('dilma x aecio          turno          eleicoes', 'neutro'),
#  ('  urnas apuradas dilma   aecio   marina   ', 'neutro'),
#  ('programas sociais tipo bolsa familia dilma garante votos classes d correspondem quanto ',
#   'positivo'),
#  ('serio dilma vai ganhar bosta novo    to acompanhando eleicoes merda ',
#   'positivo'),
#  (' turno presidente  dilma aecio ', 'neutro'),
#  ('aaaaaaah deus dilma x aecio', 'neutro'),
#  (' vai pro segundo turno aecio arrebenta dilma', 'negativo'),
#  (' dilma  ', 'neutro'),
#  ('segundo turno   dilma aecio senhora', 'neutro'),
#  ('sendo aecio dilma marina vai continuar mesma bosta vcs acham q tirar dilma vai revolucionar brasil ',
#   'negativo'),
#  ('confirmado dilma aecio  turno  eleicoes', 'positivo'),
#  ('serio alguem ficou surpreso dilma aecio segundo turno ', 'negativo'),
#  ('turno  dilma aecio forapt goaecio tiraelaporra', 'neutro'),
#  ('agora oficial segundo turno aecio dilma     deviradaaecio', 'neutro'),
#  ('turno dilma aecio', 'neutro'),
#  ('eleicoes estado dilma ganha aecio neves segue total urnas apuradas popmundi',
#   'positivo'),
#  ('achando q marina dilma segunndo turno triste  ai vc ve q vai aecio n marina pqp ',
#   'negativo'),
#  ('maioria povo ta tweetando rage nao sabe diferenca dentre dilma aecio',
#   'neutro'),
#  ('dilma aecio pro  turno', 'neutro'),
#  ('todas manifestacoes ainda votam dilma  iluminem ser humano desse',
#   'neutro'),
#  ('moral  voces sao burros p caralho  burros votou dilma ', 'negativo'),
#  ('ooooooo dilma manda cobertor orelha ai aver segundoturno voto p vc  frioooo pra raxa primahtt',
#   'negativo'),
#  ('oficial tambem  habemus  turno  dilma vs aecio', 'neutro'),
#  ('   tudo pra chegar hoje votar dilma  povo nao aprende', 'neutro'),
#  (' dias li deus nao pra andar centro culpa dilma  quase comentei opa seguranca publica eh',
#   'neutro'),
#  ('dilma aecio  q merda politica', 'negativo'),
#  ('votei aecio to feliz pra crl  serio so pena saber q ainda gente q vota dilma   nao conformo',
#   'positivo'),
#  ('dilma  cada creche   estadios', 'neutro'),
#  ('brasileiro foder vao la po  fazer manifestacao novo votar dilma ',
#   'positivo'),
#  ('luciana genro votos dilma voces ainda querem acredite nesse pais ',
#   'neutro'),
#  ('dilma pimentel venceram  valeu verdade mobilizacao povo brasil     ',
#   'neutro'),
#  ('segundo turno dilma aecio  chupaa marina ', 'negativo'),
#  ('votei dilma voces ', 'neutro'),
#  ('  agr fodeu td dilma aecio socorrro dilma nao queria competir aecio jksjak',
#   'neutro'),
#  ('dilma aecio  puta pariu', 'positivo'),
#  ('dilma  aecio  marina  henrique  kardec ', 'positivo'),
#  ('dilma va fude', 'neutro'),
#  ('dilma sapatao ganhou  cachorra', 'neutro'),
#  ('fechou dilma aecio segundo turno', 'negativo'),
#  ('confirmado segundo turno dilma x aecio', 'positivo'),
#  ('vai ser aecio x dilma ', 'positivo'),
#  (' turno aecio dilma   ', 'positivo'),
#  (' vamos torcer pro povo q votou marina  luciana votarem dilma pq senao',
#   'neutro'),
#  ('fez cola tao bonita pro pessoal votar dilma', 'positivo'),
#  ('povo cabeca pra votar dilma        ', 'neutro'),
#  ('marina    dilma    aecio    cpm    ben    onze    nx    blink    u   ',
#   'neutro'),
#  ('confirmado dilma aecio vao pro segundo turno diferenca ridicula otimo',
#   'positivo'),
#  ('dilma aecio segundo turno  ja podemos entrar panico ', 'neutro'),
#  ('confirmado  aecio neles       agora bicho pegou dilma ', 'positivo'),
#  ('deu dilma novamente sabe pq  pq brasileiro gosta ser trouxa nao basta ser trouxa vez vai ser novo',
#   'neutro'),
#  ('voce votou  dilma  aecio  luciana  marina  cpm  blink  u  nx  hevo  m  maroon  sum ',
#   'neutro'),
#  (' cris petista  distorce favor pt humano quero dizer  parte natureza humana louca lula dilma',
#   'negativo'),
#  ('dilma aecio segundo turno so faltava dilma vencer', 'positivo'),
#  ('alem q tirei   prova causa mal comida dilma', 'negativo'),
#  ('dilma aecio segundo turno pouco urnas apuradas', 'positivo'),
#  ('melhor coisa aecio  turno marina dilma preferiria morte lenta', 'positivo'),
#  ('dilma aecio definido segundo turno', 'neutro'),
#  ('dilma vence primeiro turno  aecio encosta perigosamente diferenca pouco  veja tempo  ',
#   'positivo'),
#  ('atualizou agora sc elegeu dilma  bicha  senhora indecisa hein viado ',
#   'negativo'),
#  ('agora oficial infelizmentenaodeu marina silva segundo turno confirmado dilma aecio',
#   'negativo'),
#  ('la campaanti  dilma fue bestial  aprovecharon grandes escenarios ir en su contra',
#   'negativo'),
#  (' yes  dilma bolada neles', 'neutro'),
#  ('acabou dilma x aecio', 'neutro'),
#  (' vai social  vota dilma  vai lado economico  aecio', 'positivo'),
#  ('dios dilma', 'neutro'),
#  ('confirmado  turno dilma x aecio aecio', 'positivo'),
#  ('dilma  votos dilma   votos    urnas ', 'neutro'),
#  ('ja dilma   so aceita ', 'neutro'),
#  (' concordo ctg  so queria falar contraste ensino demais ensinos publicos prefiro dilma aushuahauahs',
#   'negativo'),
#  ('quero saber ta feliz vitoria dilma     ', 'positivo'),
#  ('segundo turno dilma x aecio', 'positivo'),
#  ('thankyoudforthewwat primeira vez vou votar dilma', 'positivo'),
#  ('dilma aecio segundo turno  vergonha  vergonha  v r g n h ', 'neutro'),
#  ('globo news oficializou dilma aecio segundo turno apertem cintos  aeciodevirada',
#   'negativo'),
#  (' ala confirmado segundo turno dilma aecio  sim estao falando  vaiaram manifestacao etc so votam nela',
#   'positivo'),
#  ('acha certo votar dilma   fdp ', 'positivo'),
#  (' turno dilma x aecio votem aecio   obrigada  nada', 'neutro'),
#  ('dilma acaba pernilongo ninguem aguenta mai', 'positivo'),
#  ('dilma aecio segundo turno  voto ja aecio espero ganhe', 'positivo'),
#  ('dilma aecio  turno to catando terco aqui', 'neutro'),
#  ('definido segundo turno dilma x aecio', 'neutro'),
#  ('daonde surgiu todo povo votou aecio  porque votaram aecio    gente particularmente prefiro dilma ',
#   'positivo'),
#  ('pessoas votaram marina falando mal votaram dilma   mesma coisa sujo falando mal lavado',
#   'negativo'),
#  ('rj rs tbm votaram dilma  nao so nordeste nao votadores tiririca', 'neutro'),
#  ('kkkkkkkk raca reclamando  porem aecio humilhou dilma sc', 'neutro'),
#  ('  nenhum outro euzinha  realmente nao reclamar dilma ', 'positivo'),
#  ('cidadao brasileiro defendendo dilma militante defende jose dirceu viva alienacao pt ',
#   'positivo'),
#  (' turno  dilma aecio neves aeeeeeeee ', 'neutro'),
#  ('eita porra ja alo alo votem dilma amor deus amigos favor', 'positivo'),
#  ('dilma ganhando   cade povo q tava chingando copa ', 'negativo'),
#  (' turno  dilma aecio foradilma', 'neutro'),
#  ('vou matar dilma aecio antes segundo turno     vontade cuspir cara ',
#   'neutro'),
#  ('romario pezao dilma aecio jesus ja pode voltar  eleicoes eleicoesrj rj',
#   'neutro'),
#  ('nao entendo pra tanto protesto votaram tudo dilma novo affs partiuafundarbrasil',
#   'positivo'),
#  ('povo burro  idiota  coerencia     povo vem reclamando protestando  anos sobre governo dilma   ai   ',
#   'negativo'),
#  ('fechou dilma x aecio', 'negativo'),
#  ('parar pra pensar   dilma aecio estao segundo turno   votou marina   vai votar aecio    ',
#   'negativo'),
#  ('ruim dilma   pior t r i s', 'negativo'),
#  ('dilma partido malandro pode ate ganhar  maioria congresso    sentindo aliviada',
#   'positivo'),
#  ('brasil  pais onde pessoas fodem nao aprendem  legal elegerem dilma novo parabens pra voces viu ',
#   'positivo'),
#  ('salve corrupcao  outro privatizacao dilma aecio  ', 'neutro'),
#  ('confirmado    turno presidencial dilma  pt  x aecio neves  psdb     ',
#   'positivo'),
#  ('nao acredito dilma vai ganhar', 'positivo'),
#  ('dilma aecio turno oficial', 'neutro'),
#  ('   clarin empate tecnico marina silva y dilma en brasil  clarinmundoencuesta  ibope empate segunda vuelta marina dilma elecciones brasil   clarinete ibope y afp todos choros',
#   'negativo'),
#  ('nao votem dilma cuzao', 'neutro'),
#  ('dilma aecio segundo turno certeza deus segura pais', 'positivo'),
#  ('dilma   aecio  ', 'positivo'),
#  ('gente segundo turno dilma aecio  virada ', 'neutro'),
#  ('turno dilma aecio', 'neutro'),
#  ('vamos ser realistas ne mores  dilma vai ganhar pq infelizmente maioria vota nela',
#   'positivo'),
#  ('puta pariuu   povo burro    turno dilma aecio pqp tmc', 'negativo'),
#  ('dilma votos sao paulo vai ver porque governo excelente ne', 'positivo'),
#  ('segundo turno definido dilma x aecio  ', 'neutro'),
#  ('exterior  aecio      marina      dilma     ', 'neutro'),
#  ('voto aecio pra nao votar dilma', 'negativo'),
#  (' turno dilma x aecio', 'neutro'),
#  ('segundoturno dilma aecio', 'positivo'),
#  ('idiota dilma nao pode ganhar', 'negativo'),
#  ('quero ver aecio sendo presidente so pra ver dilma tomar cu', 'neutro'),
#  ('okay  segundo turno dilma aecio  vamos la ne', 'positivo'),
#  (' dilma menos pior favor', 'negativo'),
#  ('rt   confirmado  turno dilma aecio', 'positivo'),
#  ('aecio dilma  posso matar ', 'neutro'),
#  ('dilma ta ganhando  zzzzzz', 'neutro'),
#  ('tanto faz ganhar dilma aecio  so espero facam alguma coisa melhore brasil servicos publicos',
#   'positivo'),
#  ('segundo turno dilma aecio    ', 'negativo'),
#  ('nao dilma sim totalmente anti aecio', 'negativo'),
#  ('endeusam dilma causa bolsa familia  verdade  criou fhc', 'neutro'),
#  ('vaias xingamentos contra dilma   copa aqui votaram nela    vai entender povo  ',
#   'neutro'),
#  (' eduardo jorge rainha  dilma aecio nadinha                                 ',
#   'neutro'),
#  ('entao gente  tchau segundo turno aecio dilma confirmados pode deitar chao chorar ja',
#   'positivo'),
#  ('nao acredito tudo brasileiros votaram dilma', 'neutro'),
#  ('tias votaram dilma motivos casa vida', 'neutro'),
#  ('vai ter segundo turno vamo vamo  dilma ', 'neutro'),
#  ('nunca confie pesquisas    partiu velorio dilma  chuuuuupa dilmaaaaaaaa bruxa  ',
#   'neutro'),
#  (' turno dilma aecio kakakaka', 'neutro'),
#  ('chora dilma aecio segundo turno', 'neutro'),
#  ('fala serio  aecio dilma n sei pior', 'negativo'),
#  ('  turno dilma aecio zzzzz', 'neutro'),
#  ('oficial dilma aecio segundo turno', 'neutro'),
#  ('dilma aecio vao disputar segundo turno ', 'neutro'),
#  ('rede b eleicoes dilma roussef aecio neves irao  turno  ate momento apurados   urnas   ',
#   'neutro'),
#  ('dilma segundo turno aecio  vou rir qlqr dois ganharem  ainda dilma ',
#   'positivo'),
#  ('nao acredito povo pra rua protestou  falou q pais ta lixo agr votaram dilma  seadilmaganharosonibusvaoqueimar',
#   'negativo'),
#  ('dilma aecio brasil merece viu povo nao aprende    ', 'neutro'),
#  ('dilma vai ser presidenta novo caostotal', 'positivo'),
#  ('tudo pra chegar hoje votar dilma   ta louco', 'negativo'),
#  ('dilma aecio turno', 'neutro'),
#  ('nao dar entender povo brasileiro   faz protesto   quebra porra toda dps vota dilma pera ai ne     ',
#   'negativo'),
#  ('agora marina silva apoia dilma   aecio vai ficar neutra ', 'neutro'),
#  ('boca urna ibope mostra turno sera dilma aecio  msnpt brbbhn i  aecio neves dilma vai ver bom  ',
#   'neutro'),
#  ('pessoas q pra rua votam dilma tao coerente quanto homossexuais q desejam ter familia legal  igualdade votam marina',
#   'positivo'),
#  ('votam dilma reclamam brasil merda   putos', 'negativo'),
#  ('vaiam dilma durante copa  protestaram contra reclamaram governo anos inteiros  povo burro  pede p sofrer',
#   'negativo'),
#  ('pt  dilma   favor igualdade social', 'positivo'),
#  ('segundo turno dilma lixo aecio lixo', 'neutro'),
#  ('confirmou dilma aecio segundoturno dilmapravencer', 'positivo'),
#  (' quantos estados existem brasil ne so causa nordeste dilma vai ganhar perder nao querido',
#   'positivo'),
#  ('dilma aecio ai deus', 'neutro'),
#  ('segundo turno definido dilma aecio', 'neutro'),
#  ('una hipotetica derrota dilma rousseff en segunda vuelta  cambiaria el escenario politico sudamericano',
#   'negativo'),
#  ('dilma aecio turno  baa', 'neutro'),
#  ('pra vcs nao gostam dilma   pensem bem antes pedir pais governado aecioporto po',
#   'neutro'),
#  ('dilma aecio segundo turmo medo', 'negativo'),
#  ('definido  dilma aecio segundo turno', 'neutro'),
#  ('bahia   dilma vempraurna eleicoes  ', 'neutro'),
#  ('aecio dilma segundo turno', 'positivo'),
#  ('fecho agora votar dilma aecio', 'neutro'),
#  ('confirmado aecio sera adversario dilma segundo turno eleicao presidencial',
#   'positivo'),
#  ('porra  nao acredito dilma vai ganhar novo', 'positivo'),
#  ('agora dilma  ', 'neutro'),
#  ('fudeu dilma    ', 'neutro'),
#  ('dilma ganhe fim', 'positivo'),
#  ('  pregunta la ven dilma la segunda vuelta   complicado ', 'positivo'),
#  ('gente idade pra votar querendo pagar sei tudo icon  dilma   toca',
#   'neutro'),
#  ('novela chamada dilma x aecio', 'neutro'),
#  ('menos pior dilma vcs quer faca', 'negativo'),
#  ('vai ter segundo turno dilma aecio ate agora', 'positivo'),
#  ('pessoal  eleitores marina nordeste probabilidade votar dilma   exemplo disso pernambuco  dilmapravencer',
#   'neutro'),
#  ('segundo turno  aecio dilma ', 'neutro'),
#  ('dilma aecio segundo turno', 'neutro'),
#  ('dilma aecio segundo turno comprovado eita giovana vai dar aecio',
#   'negativo'),
#  ('rezando p votou dilma', 'neutro'),
#  ('aecio juntou dilma fizeram pacto capiroto', 'neutro'),
#  ('  odiar dilma aercio coisa  odiar nordestinos outra', 'negativo'),
#  ('segundo turno dilma   aecio  ', 'negativo'),
#  ('voto dilma nao voto noia constroi aeroporto particular dinheiro publico retrocesso nao voto dilma ',
#   'neutro'),
#  ('dilma aecio pf   ', 'neutro'),
#  ('alo aecio dilma   favor fazer debate deve ser  propostas tal  nao quero debate mimimi',
#   'neutro'),
#  ('nao acredito aecio dilma vao pro segundo turno', 'negativo'),
#  ('globo tao comprada q n sabe vai pra  turno dilma kkkkk acordaglobo',
#   'neutro'),
#  (' la empavaste vota x dilma pa q gane el otro jajaja', 'positivo'),
#  (' densinflo completamente marinanunca tuvo esos votosy opero globo restarle caudal votantes dilma y el pt',
#   'positivo'),
#  ('amor deus tarso dilma precisam ganhar senao certeza q pai troco',
#   'positivo'),
#  ('revoltante ver pessoal nordeste vota pra dilma causa bolsa familia',
#   'negativo'),
#  ('globo news afirma marina sao paulo segundo turno nao irao dilma  petistas estao falando vou contestar ',
#   'negativo'),
#  (' antes aecio dilma ', 'neutro'),
#  ('   brasil con   escrutado neves  marina   dilma ira dormir con diarrea noche ',
#   'neutro'),
#  ('antes luciana  marina  dilma eduardo jorge aecio plmdds', 'neutro'),
#  ('matematicamente definido segundo turno dilma aecio', 'neutro'),
#  (' turno dilma x aecio', 'neutro'),
#  ('vei dilma ganhar brasil ta fudido  ', 'negativo'),
#  ('segundo turno confirmado dilma x aecio', 'positivo'),
#  ('aecio x dilma', 'negativo'),
#  ('dilma aecio segundo turno eita brasil   ', 'negativo'),
#  ('aecio dilma  turno confirmado', 'positivo'),
#  ('erro ibope comprado  ontem dilma   hoje   ontem aecio   hoje   ontem marina   hoje   ontem veiga   hoje  ',
#   'neutro'),
#  ('br bem merece dilma aecio rs', 'neutro'),
#  ('dilma aecio pro segundo turno  belezura', 'neutro'),
#  ('segundo turno aecio dilma deuses', 'neutro'),
#  ('primeiro gente fala q globo eh coisa alienado  acredita tudo q falam dilma   ta parabens viu',
#   'positivo'),
#  ('dilma aecio segundo turno boa sorte ', 'positivo'),
#  (' sim cara  nego ta tao cego c q n percebe q n dilma vai ser cara tao corrupto ',
#   'negativo'),
#  ('vamos ver aecio ganha nesse segundo turno dilma favor', 'positivo'),
#  ('possivel nao querer aecio dilma presidencia      ', 'neutro'),
#  (' dilma aecio segundo turno passagem pra marte ai ', 'negativo'),
#  ('cara vai botar fodendo dilma', 'negativo'),
#  ('entendam coisa  pessoal sp quer tudo  menos dilma   menos pt', 'positivo'),
#  ('eita dilma aecio segundo turno', 'neutro'),
#  ('dilma marina ainda alguma chance marina ganhar vai ser aecio dilma  ',
#   'positivo'),
#  ('nao contra bolsa familia  atualmente logica vejo  chave governo dilma pra continuar',
#   'neutro'),
#  ('fico puta vai rua fazer protesto vota dilma  algo errado ai ne  ',
#   'neutro'),
#  ('galera  aecio dilma segundo turno  definido', 'neutro'),
#  ('pra cada paulista q xinga nordeste conta votacao dilma   cuia sera doada ptomar banho rio tiete dilmapravencer',
#   'neutro'),
#  ('   dilma aecio estao confirmados segundo turno  tribunan ', 'positivo'),
#  ('to vendo ja  dilma vai ganhar sa bosta', 'positivo'),
#  ('der dilma novo mudo p egito', 'neutro'),
#  ('votei marina infelizmente dilma vai ganhar  fizeram tanto protesto pra nada',
#   'positivo'),
#  ('caramba dilma nao pode ganhar vez', 'negativo'),
#  ('dilma presidente robinho selecao parece voltamos pra ', 'neutro'),
#  ('dilma   aecio   boa sensacao ganhar prazo', 'positivo'),
#  ('dilma aecio  turno muda planeta ', 'negativo'),
#  ('dilma aecio segundo turno  dificil escolher', 'negativo'),
#  ('dilma   prepare  hora chegou    virada aecio aeciosambandonadilma aeciodevirada aeciopresidente',
#   'negativo'),
#  ('bora tirar dilma porra', 'positivo'),
#  ('dilma frente geraldo alckmim ganhando tambem', 'positivo'),
#  ('dilma aercio zzzzz', 'neutro'),
#  ('segundo turno dilma aecio voto agora vai ser disputado tapa', 'neutro'),
#  ('mano vcs parassem ser falsos fazessem q falam lucianinha vcs tava turno c dilma massss ne  acho bom',
#   'positivo'),
#  ('aecio dilma  marina apoiando aecio vai ser foda pra dilma ', 'negativo'),
#  ('nego nao entende q dilma merda', 'neutro'),
#  ('reclamam pra crl dilma   vaiam smp q aparecia vai vota filha puta novo  mano vcs q votaram nela merda cabeca    ',
#   'negativo'),
#  ('cabou  galera aecio dilma segundo turno  gglobopoliticaeleic oesapuracao votos presidente ',
#   'neutro'),
#  ('dilma aecio segundo turno  vishh', 'neutro'),
#  ('urnas apuradas   turno deve ser dilma aecio   eleicoes pictwitterlavzfpjd',
#   'neutro'),
#  ('dilma aecio segundo turno pqp fodidos ', 'negativo'),
#  ('  oe  vi vcs tl cheguei dhejshsi  cara  tbm favor dilma   menos vcs tbm  n vejo quase ngm favor',
#   'negativo'),
#  ('aecio veia dilma cadeia', 'neutro'),
#  ('dilma ganara la vuelta mirando atras', 'positivo'),
#  ('dilma aecio  eita porra', 'negativo'),
#  ('coisa q achava q iria ver dilma q apagada nessas eleicoes povo vai pra rua acaba c mulher',
#   'positivo'),
#  ('dilma aecio voto juliana desmaiada', 'neutro'),
#  (' vo anular voto uu recuso dilma aecio uu', 'neutro'),
#  ('milhao vezes dilma marina segundo turno lixo aecio', 'negativo'),
#  ('voces reclamam dilma   entao coloquem psdb poder dps nao facam manifestacoes ridiculas contra governo',
#   'negativo'),
#  ('   definido dilma  pt  aecio  psdb  vao disputar segundo turno  globoswqslt eleicoes g  marina  pf  n apoie ngm',
#   'negativo'),
#  ('burrada achar aecio vai ser melhor dilma ', 'negativo'),
#  ('so come muita merda pra preferir aecio dilma', 'negativo'),
#  ('pesquisa sc tava dilma primeiro aecio terceiro  acho nao', 'positivo'),
#  ('alaa ala  turno dilma aecio', 'neutro'),
#  ('dilma aecio turno aecio confio voce filho', 'neutro'),
#  ('so eh lixo pq ngm sabe colocar mao consciencia n cometer erro novo  dilma ja chame so fez merda vai caga',
#   'negativo'),
#  ('oficial segundo turno dilma aecio', 'neutro'),
#  ('segundo turno dilma aecio gosto assimmmmmm', 'neutro'),
#  ('to vendo q sera dilma  affffsjhahhsh', 'neutro'),
#  ('dilma aecio  turno aeeew', 'negativo'),
#  (' campanha nazista aecio dilma contra marina votarei nulo', 'neutro'),
#  ('segundo turno dilma aecio  agora porra fico ', 'negativo'),
#  ('turno  aecio vagaba dilma', 'neutro'),
#  ('mano nao gosto aecio dilma comentarios  porra faco nesse segundo turno ',
#   'negativo'),
#  (' turno  dilma aecio magina populacao toda anula  acontece ', 'neutro'),
#  ('pouxa segundo turmo dilma aecio pouxa ', 'neutro'),
#  (' dilma segundo turno duvidas', 'negativo'),
#  ('fechou segundo turno dilma x aecio', 'negativo'),
#  ('impeachment dilma queriam faze ano passado', 'neutro'),
#  ('dilma ganha dnv', 'positivo'),
#  ('dilma deve ta cu mao pra segundo turno', 'negativo'),
#  ('confirmado dilma aecio turno', 'positivo'),
#  ('redatores veja devem estar indo loucura uuuuhuhuhuh chupa marina escrotaaa vamo esculachar dilma agora nois',
#   'negativo'),
#  ('ia votar dilma baidu instalado tambem fez mesma coisa danilo gentili   ',
#   'neutro'),
#  ('brasil grande  maioria estado sp votou aecio  norte brasil tudo dilma auhue',
#   'positivo'),
#  ('segundo turno dilma aecio ', 'neutro'),
#  ('foda  desde dilma vaze segundo turno pfvr', 'negativo'),
#  ('dilma rousseff encabeza sondeo boca urna en brasil  ', 'neutro'),
#  ('revista americana lista  motivos nao reeleger dilma faz sucesso redes sociais  ',
#   'positivo'),
#  ('definido  dilma  pt  aecio neves  psdb  estao segundo turno', 'neutro'),
#  ('feito  turno dilma aecio', 'neutro'),
#  ('aecio dilma segundo turno serio', 'negativo'),
#  ('odeio pobres mal informados so vota dilma medo perder bolsa familia',
#   'negativo'),
#  ('dilma vs aecio eita', 'negativo'),
#  ('nao aguento povo falando politica  eleicao  dilma   sei la  ohhhh caralho',
#   'neutro'),
#  ('danilo gentili faz video piada voto dilma vai ditadura cubana  ', 'neutro'),
#  ('vo votar dilma bjoks pra vcs forapt', 'neutro'),
#  ('dilma aecio segundo turno nao', 'neutro'),
#  ('presidente   dilma rouseff     aecio neves     marina silva   ', 'neutro'),
#  ('segundo turno aecio dilma     confirmado', 'positivo'),
#  ('queria luciana ne  ja nao vai rolar  dilma', 'neutro'),
#  ('povo reclama  reclama vota dilma   vai entender cara', 'neutro'),
#  ('adeus dilma ', 'neutro'),
#  ('queria tanto nao segundo turno ainda dilma ', 'positivo'),
#  (' claro qe nao  nousso amour maior qe dilma aecio', 'neutro'),
#  ('segundo turno confirmado dilma aecio dilmapravencer', 'positivo'),
#  ('to revoltada dilma ganhando votos', 'neutro'),
#  ('dilma nao mano  pqp', 'neutro'),
#  ('dilma   rainha negra vai segundo turno ', 'negativo'),
#  ('pfvr vao falando varios motivos pq dilma melhor aecio  pq to dando  menina nao acredita mim',
#   'positivo'),
#  ('dilma aecio  serio  serio ', 'negativo'),
#  (' agora naoaecio ainda nao usou carta embaixo mangacuida dilma ', 'neutro'),
#  (' admiro fhc pra caralho  embora achado mandato merda   ja aecio desprezo dilma nao excelente',
#   'negativo'),
#  (' sei la  acredito dilma reeleita nao melhora  vai simplesmente ficar jeito ta ',
#   'neutro'),
#  ('segundo turno aecio x dilma  beem feito marina ', 'negativo'),
#  ('dilma x aecio  segundo turno  povo burro  falo ', 'neutro'),
#  ('duas merdas indo pro segundo turnodeixa logo dilma', 'negativo'),
#  ('romario bolsonaro garotinho aecio dilma  marina pezao lindberg clarissa cabral crivella nunca representarao ',
#   'negativo'),
#  ('dilma segundo turno   assim   caralho quebraram rio janeiro todo pra votar nela novamente   ',
#   'negativo'),
#  (' pior ta nao fica  dilma ganhar sim', 'positivo'),
#  ('confirmado segundo turno presidente dilma aecio neves', 'positivo'),
#  ('dilma four pro turno aecio vey aeciooooooo merda', 'negativo'),
#  ('segundo turno decidido dilma aecio', 'neutro'),
#  ('dilma aecio  palmas', 'positivo'),
#  ('dilma aecio segundo turno  dilma gente  dilma  vao foder', 'neutro'),
#  ('ta hora dilma ralar peito', 'neutro'),
#  ('reclama q brasil merda dps vota dilma kkkkk', 'negativo'),
#  ('nao curto dilma nao sei pq tbm dizer nao fez nada mano ai tbm eh demais ne',
#   'neutro'),
#  ('turno aecio dilma  ', 'neutro'),
#  ('agora oficial dilma aecio  turno lerigou br', 'neutro'),
#  ('aecio neves disputa segundo turno dilma  ', 'negativo'),
#  ('   tudo pra chegar hoje votar dilma  pictwitterjcthnjejje ', 'neutro'),
#  ('merval disse votacao marina  sao paulo  nao ira dilma ', 'neutro'),
#  ('povo fala fala dilma ta la primeiro  nojo vcs', 'positivo'),
#  ('pior nao dilma pior luciana genro preocupante', 'negativo'),
#  ('pessoal agradeco todos votaram jair messias bolsonaro primeiro passo mudar brasil dilma pt',
#   'positivo'),
#  ('vcs ficam falando so nordeste vota dilma ate mg ganhou hein nao esquecam q nordeste muitos estados n generalizem',
#   'positivo'),
#  (' olha urnas ai dilma ganha lavada dificil nao pensar diferente', 'neutro'),
#  ('gente tela dizendo aecio melhor dilma   rico come lixo ', 'positivo'),
#  ('dilma aecio neves segundo turno aqui esperando duardo jorge presidente vcs vem ai decepcao vcs',
#   'negativo'),
#  ('aff  aecio x dilma', 'neutro'),
#  ('dilma aecio segundo turno bora dia  outubro', 'neutro'),
#  ('segundo turno confirmado aecio dilma sinceramente', 'positivo'),
#  ('hora dilma deu  cosada saco pensou fudeu', 'neutro'),
#  (' toda contraditoria  assusto prefiro apoio ter anos dilma', 'positivo'),
# ...
#   'neutro'),
#  ('   dilma so vence norte nordesta  sabe significa   nordeste so gente otaria',
#   'positivo'),
#  ('aecio dilma   turno aff gente votem aecio', 'positivo'),
#  ('nao diga segundo turno dilma aecio novidade', 'neutro'),
#  ('segundo turno dilma x aecio ', 'neutro'),
#  ('agora babacas fizeram protesto  votem dilma novo bando boco  terceira guerra mundial pra voces',
#   'positivo'),
#  ('segundo turno aecio ira atropelar dilma', 'neutro'),
#  ('dilma aeciokkkkkkkkkkkkkk lancamentomesintotaobemdia', 'neutro'),
#  ('gente fala n votar dilma ingrato pq prouni pictwitternlpvoybrmx', 'neutro'),
#  ('todos protestos pra chega vota dilma ', 'neutro'),
#  ('nao entendo logica povo brasileiro protestaram ate nao poder hoje votaram dilma  sera gigante acordou ',
#   'neutro'),
#  ('dilma ganhar dnv brasil vai dever cartaz protesto', 'positivo'),
#  (' le tml cinco minutos so gente falando protestou tanto pra votar dilma novo',
#   'positivo'),
#  ('dilma aeciio segundo turno', 'negativo'),
#  ('foda galera fala prefiro dilma arriscar alguem pior afe cara', 'negativo'),
#  (' tbm nao chega dilma   ', 'neutro'),
#  (' dilma ta topo', 'positivo'),
#  ('votos presidente apenas rs     votos apurados  dilma     aecio    marina    luciana genro   ',
#   'neutro'),
#  ('   ai povo faz tudo pra final votar dilma   brasileiro merece sofrer pictwitterbdsjxyxep  exato',
#   'positivo'),
#  ('sobre dilma estar frente pros porcos basta lama', 'neutro'),
#  (' acha dilma perde ', 'negativo'),
#  ('dilma aecio   dilma ', 'positivo'),
#  ('protestam ano inteiro  ai vao la urna votam dilma  pa ra bens', 'positivo'),
#  ('voto dilma   dana vcs', 'neutro'),
#  ('sobre meta tirar dilma poder were half way there       desculpeotranstornoestamosmudandoobrasil',
#   'negativo'),
#  (' ah louis  ate vc dilma   decepcionadissima', 'negativo'),
#  ('confirmado dilma x aecio', 'positivo'),
#  ('dilma aecio estao confirmados segundo turno  tribunan', 'positivo'),
#  (' sim dilma   aecio marina  ja dilma agora acho luciana otima  vdd  socialismo mt radical',
#   'positivo'),
#  ('dilma fudeu', 'negativo'),
#  ('dilma aecio segundo turno vcs podem votar pensem bem amor deus',
#   'positivo'),
#  ('timeline ta briga dilma x aecio ta dando gosto gosto chorume', 'neutro'),
#  ('maioria votou dilma so causa bolsa familia', 'neutro'),
#  ('dilma aecio turno', 'neutro'),
#  ('voces estao fazendo tanto protesto pq dilma pro segundo turno aposto hoje cedo voto ',
#   'neutro'),
#  ('tenis bermuda camisa bone   tenis bermuda camisa bone  sempre volta dilma   cabeca pes   ',
#   'neutro'),
#  ('pede mudanca  fala q gigante acordou  porem vota dilma', 'neutro'),
#  ('vejo tanto gente tl pras ruas protestar ta nessa dilma melhor amorrr',
#   'positivo'),
#  (' hola si segun la propia dilma hay ballotage  ', 'positivo'),
#  (' to falando estao falando nao queriam dilma aecio opcao', 'neutro'),
#  ('dilma precisa ganhar porra', 'positivo'),
#  ('exausta vota dilma   povo burra  gente nao sabe nada exausta  exausta exaustaaaaaaaaaa',
#   'negativo'),
#  (' turno confirmadissimo aecio dilma ', 'positivo'),
#  ('vai dilma aecio pro seg turno', 'negativo'),
#  ('elecciones en brasil dilma rousseff y aecio neves van segunda vuelta  octubre  los primeros resultad  ',
#   'positivo'),
#  (' pooow malena dilma explica pra q fizeram toda ocnfusao ano passado pra votar pt novo',
#   'neutro'),
#  ('dia antes eleicoes   diferenca dilma aecio  agora apenas   pode pictwittervlwvnlub',
#   'neutro'),
#  ('dilma   votos', 'neutro'),
#  ('quero brasil foda agora dilma vai terminar afundar pais  parabens pra votou nela ',
#   'negativo'),
#  ('dilma aecio segundo turno adeus', 'neutro'),
#  ('dilma competente candidatos', 'positivo'),
#  ('povo ignorante  reclamou tanto hora urna votou dilma', 'negativo'),
#  ('dilma aecio ', 'positivo'),
#  ('fazem puta protesto fica dias ruas  pra chegar dia eleicao votar dilma',
#   'neutro'),
#  ('dilma mal humorada durante campanha  apesar pesquisas partir agora  vou fiar humor institutos',
#   'negativo'),
#  (' maaaan kkk corrupcao governo dilma sao palavras totalmente diferentes ne  kkkkkkk',
#   'neutro'),
#  ('odeio dilma   odeio aecio dois  melhor deixar merda instavel jeito ta ha  anos',
#   'negativo'),
#  ('marina silva es una binner aecio neves es un macri vamos dilma   superclasico',
#   'neutro'),
#  ('brasil ta fundo poco sim dilma continuar topo brasil so vai afundar ',
#   'positivo'),
#  ('dilma rousseff y aecio neves disputaran la presidencia brasil en el ballottage  infobaec via ',
#   'neutro'),
#  ('votei branco q lixo voto pra vaca dilma  seadilmaganharosonibusvaoqueimar',
#   'negativo'),
#  ('curral eleitoral obrigacao eleger dilma primeiro turno nao conseguiu acho algo errado',
#   'positivo'),
#  ('euvoteimarina nao arrependo lavo maos dessa politica nojenta paocirco veremos  turno dilma aecio',
#   'negativo'),
#  (' verdade dilma q ja cadeia', 'negativo'),
#  ('jurava q ia ser dilma marina mano  aecio surpreendeu', 'positivo'),
#  ('neste momento resultado votos apurados presidente dilma aecio neves   ',
#   'neutro'),
#  ('confirmado  turno dilma aecio', 'positivo'),
#  ('nesses  anos reeleicao dilma protesto  cada porrada policia sentar povo vou achar bem empregado ',
#   'neutro'),
#  ('chupaaaa dilma', 'negativo'),
#  ('dilma naooooooooooooooooooooooooooooooooo', 'negativo'),
#  ('dilma aecio segundo turno     ', 'positivo'),
#  (' turno brasil dilma roussef x aecio neves eleicoes', 'neutro'),
#  ('preciso lembrar mudanca urnas feita  principalmente  poder legislativo gente crise porque dilma aecio lideram',
#   'positivo'),
#  ('quero ver rolar debate  aecio vai destruir dilma   ', 'negativo'),
#  (' turno dilma aecio comentarios', 'neutro'),
#  ('queria estar morta dilma ganhando ', 'positivo'),
#  (' gigante acordou  votou dilma voltou dormir agora anos     preparando malas paris  to chegando',
#   'positivo'),
#  ('gnt nao queira dilma vai ganhar aceitem doi menos', 'positivo'),
#  ('dilma paaaaaaaau tb nfd', 'neutro'),
#  ('secoes apuradas presidente dilma pt  turno     votos aecio neves  ',
#   'neutro'),
#  (' sinceramente dilma aecio   vo vota dilma   qualquer dois ganhar vai mesma merda   ',
#   'positivo'),
#  ('ajustado triunfo brasil dilma sobre aecio   el  en las encuestas  pictwittertuziybnjip',
#   'neutro'),
#  ('senti vergonha brasil perdeu x pra alemanha ver dilma aecio concorrendo  nojo euvoteimarina',
#   'neutro'),
#  (' engracado vc veio falar nordeste causa dilma   mente tao pequena tao futil parece q nao sabe',
#   'neutro'),
#  ('ta vendo dilma aecio  nao voto morto aecio euvoteimarina', 'positivo'),
#  ('disputa presidencial aponta segundo turno dilma aecio eleicoes', 'neutro'),
#  ('dilma x aecio  definido segundo turno  pictwitterrfspclax', 'neutro'),
#  ('pessoa fala nao quer aecio dilma   ta ai defendendo pt', 'positivo'),
#  ('presidencia   votos apurados  dilma  pt      aecio    marina   ', 'neutro'),
#  ('dilma liverpool aecio city final temporada passada', 'neutro'),
#  ('agora aecio vai inventar tudo proposta parecidas dilma ', 'neutro'),
#  ('jonas marra hackeou sistema votos dilma acordem', 'neutro'),
#  ('dilma termina primeiro turno votos  aecio surpreende atinge    aovivofolhauolbr  aovivos ',
#   'positivo'),
#  (' ta sim  aecio dilma pro segundo turno', 'negativo'),
#  ('infelizmente nao faco parte elite brasileira pra votar aecio nao   familia eh funcionario publico   dilma',
#   'positivo'),
#  ('oq adiantou fazer protestos votarem dilma novo', 'positivo'),
#  ('dilma nao ganha  turno mandar passinho baile alta', 'negativo'),
#  ('aonde voces estao cabeca  dilma novo  caralhoooooooooooooooooo', 'neutro'),
#  ('vi algum filho puta falando mal nordeste pq infelizmente votaram dilma vou dar unfollow',
#   'negativo'),
#  ('hahahaha disse dilma aecio  ', 'positivo'),
#  ('apuracao presidente    urnas apuradas pais dilma contra   aecio neves marina cresce   pictwitterfkzztjiafs ',
#   'neutro'),
#  ('dilma vai ganhar obaaaa ja sabia podem chamar qualquer coisa dilma ',
#   'positivo'),
#  ('con el  ciento del pado electoral escrutado dilma   ciento  aecio neves   ciento',
#   'neutro'),
#  ('dilma     y neves     van en segunda vuelta  googl brasil', 'negativo'),
#  ('tudo  pra chegar dia verdadeira manifestacao voltar dilma aecio    pictwitterzzsrgzxaln',
#   'positivo'),
#  (' nao pode kra akfjhsjhgl votei marina  der segundo turno dilma x aecio  voto aecio',
#   'neutro'),
#  (' minas contramao brasil   infelizmente  elegemos caixa mensalao elegendo dilma aqui ',
#   'positivo'),
#  ('dilma caralho    ', 'neutro'),
#  ('oloocoo dilma ta primeiro ', 'positivo'),
#  ('      culpa nordeste  nordestinos morre bolsa familia morto fome dilma aecio euvoteimarina ',
#   'negativo'),
#  ('ter q votar aecio pra dilma n ser reeleita triste  saida', 'negativo'),
#  ('olha  pior dilma aecio  so galera endeusando luciana ta foda ', 'negativo'),
#  ('confirmado segundo turno dilma aecio eleicoes', 'positivo'),
#  ('dilma   aecio  ', 'positivo'),
#  ('salve corrupcao  outro privatizacao dilma aecio', 'neutro'),
#  ('aporrea  elecciones en brasil dilma rousseff y aecio neves van segunda vuelta  oct    ',
#   'negativo'),
#  ('elecciones en brasil dilma rousseff y aecio neves van segunda vuelta   via  ',
#   'negativo'),
#  ('agora  cada defina melhor tatica aecio todos contra dilma   comecando agoran to nessa ',
#   'positivo'),
#  ('hoje dia ta menos assim cala boca voce votou dilma ', 'positivo'),
#  ('so vcs nao sabiam dilma ia ter maior pontuacao', 'neutro'),
#  (' nessa ferrou  atacou demais dilma nisso iria votar marina pt  pensou vou aecio entao',
#   'neutro'),
#  (' sim  porque nada virou defensor dilma  auhauhauhauhuaha', 'neutro'),
#  ('nao sei pior dilma aecio', 'negativo'),
#  ('povo ta loco acha todos eleitores eduardo jorge luciana votado dilma   nao ia rolar segundo turno',
#   'negativo'),
#  ('dilma capaz vir pra sc pedir voto trouxa ainda votam nela', 'negativo'),
#  ('paulo camara derrota armando monteiro  lula dilma pernambuco coisa linda ler ',
#   'positivo'),
#  (' sei melhor vc votar dilma kkkk', 'positivo'),
#  (' amiga pra vc ve nao tao errada assim  aecio tao competente proprio estado votou dilma ',
#   'positivo'),
#  ('estao surpresos dilma estar ganhando minas  saibam belo horizonte',
#   'positivo'),
#  ('   dilmapravencer   pictwitterhhwsphnuk  gigantas america laina todos con dilma ',
#   'neutro'),
#  (' incrivel gente defendendo dona dilma ', 'positivo'),
#  ('aecio dilma cara', 'positivo'),
#  ('trabalhador brasileiro gosta sofrer so pode  povo reclama todo dia inferno pais ai pessoa vai la vota dilma pqp',
#   'neutro'),
#  ('n sei q pior dilma ganhar aecio ganhar  pra tirar sapata to aceitando qualquer merda',
#   'positivo'),
#  ('sei la dilma  mandou  bilhoes reais pro porto cuba nao afeta leitura chorume comunismo eh bom ne fera',
#   'positivo'),
#  ('dilma rindo voces  otarios  votarem nela vai rir ainda anos cara puta pariu ',
#   'positivo'),
#  ('epa     escrutado    votos dilma rousseff lidera   davta  cnnitrxfvt pictwitterplhkgvilfw brasildecide',
#   'neutro'),
#  ('eleitores eleitores nao aecio nao pfvr eleitores lu genro dilma eduardo sim aecio nao eleitores plmdds eleitoresssssss eleitores nao',
#   'positivo'),
#  ('votos marina repartirem partes iguais  dilma leva aecio convencer  marineiros',
#   'neutro'),
#  ('nao consigo entender alguem sa consciencia vota dilma', 'neutro'),
#  ('dilma aecio  mil vezes aecio  nao volto vai fica ', 'positivo'),
#  ('nao favor dilma longe disso', 'positivo'),
#  ('vai ter ser ne dilma nao nao   agora seguinte teamaecio ', 'neutro'),
#  ('vi gente usa fies mcmv votando aecio falando dilma tava ruim pro brasil',
#   'negativo'),
#  ('agora aecio dilma confirmado segundo turno', 'positivo'),
#  ('sao paulo dilma rousseff marina silva empate tecnico', 'neutro'),
#  ('idiotas votaram dilma nao viu debate', 'negativo'),
#  ('reclama dilma vota aecio sabe nada inocente ', 'positivo'),
#  ('vota marina   nao vota dilma      foradilma agoraeaecio', 'neutro'),
#  ('povo vota dilma so q ganham bolsa familia vcs soubessem q bolsa familia ajuda mt varias casas n falariam ',
#   'neutro'),
#  ('dilma aecio segundo turno prefiro assistir s teen wolf ate morre intoxicada',
#   'neutro'),
#  ('ai mae diz q diolma ganhar vai ver mudarmos p outro pais vai dilma',
#   'positivo'),
#  ('dilma ganho  ', 'neutro'),
#  (' hahahahaahahahahaa rindo  p ia votar edu  nao lembrava numero hahahaha fiquei dilma',
#   'positivo'),
#  ('ja ta definido dilma vs aecio segundo turno so otimas opcoes rs ainda acredito sartori',
#   'positivo'),
#  (' okay dilma nao melhor votar  votar aecio muita burrice', 'positivo'),
#  ('vem falar quer brasil melhor  melhor votando dilma  ', 'positivo'),
#  (' dilma obvio ia ser nulo  outros n sei amiga', 'neutro'),
#  ('povo ta votando dilma n fila inteligencia antes nascer', 'neutro'),
#  ('aecio tanto fala governos maravilhosos minas  perdeu pra dilma proprio estado hahahaha patetico',
#   'positivo'),
#  (' nao votei dilma kkkkkkk  deus livre comestobrazilcaptainjack', 'positivo'),
#  ('aii criatura passa quatro anos reclamanfo dilma ai vai vota nela criatua erra humano percisti erro burrice',
#   'positivo'),
#  ('dilma so ganhou causa bolsa familia', 'neutro'),
#  ('dilma presidenta brasil constanza senadora uruguay  la cual en  espero decir con todo mi orgullo presidenta pictwitterypacmwtlps',
#   'neutro'),
#  ('  nao espere marineiros votando presidenta dilma  sos', 'neutro'),
#  ('dilma rousseff logra  ciento en comicios  segun sondeo  lnisiftttfidee',
#   'neutro'),
#  (' porque nordeste dilma votada', 'positivo'),
#  ('mesma galera manifestacoes  votaram dilma   mds', 'positivo'),
#  ('chupa dilma       fato  ', 'negativo'),
#  ('nao votei hoje nao voto porra nenhuma nesse mundo  vai todo mundo votou dilma pezao tomar   ',
#   'positivo'),
#  ('povo brasileiro fala fala fala fala fala fala fala fala fala chega hora h vota dilma pqp          pra mim chega',
#   'neutro'),
#  ('melhor dilma marina aecio menos brasil nao vai ficar bosta ja ta',
#   'positivo'),
#  ('levar uns tapas cara todo mundo votou dilma', 'neutro'),
#  ('so quero ver  gente sofrer anos causa varios retardados votaram dilma emabiggestfansjustinbieber',
#   'negativo'),
#  ('turno dilma aecio', 'negativo'),
#  ('   brasil con   escrutado neves  marina   dilma ira dormir con diarrea noche hacen falta  maquinas smarmatic',
#   'neutro'),
#  ('sera povo vaiou dilma ainda voto nela   so burros ne    ', 'negativo'),
#  ('gana dilma confirmase habera segunda volta   via crtvg', 'positivo'),
#  ('   urnas apuradas todo brasil  dilma      segundo turno  aecio neves      segundo turno  marina silva     ',
#   'negativo'),
#  ('dilma aecio  fico dilma  euvoteimarina', 'neutro'),
#  ('atencao dilma rousseff aecio neves disputarao segundo turno presidencia republica',
#   'negativo'),
#  ('criatura vota dilma quer brasil melhor  vai entender', 'positivo'),
#  ('dilma resto aborto', 'neutro'),
#  (' pois ta hora desmentir dilma   ja quero dilma recorrendo bolsa familia pra n responder rs',
#   'neutro'),
#  ('marina tira votos aecio dilma   bem capaz ate obvio votos voltem pro aecio',
#   'positivo'),
#  ('eleicoes estado sc  aecio neves ganha dilma segue total urnas apuradas popmundi',
#   'positivo'),
#  ('rousseff gano primera vuelta y disputara la segunda con neves la presidenta brasiledilma rousseff  fue la ma  iftttcduzd',
#   'positivo'),
#  ('rio janeiro     urnas apuradas     dilma     aecio     marina genteeeeeeeee rio  ',
#   'neutro'),
#  ('apuracao votos dilma    aecio neves    marina silva   paciencia ta comecando  ',
#   'neutro'),
#  ('al secondo turno dellelezione in brasile arriva dilma  pt  aecioneves psdb  lappoggio di marina  psb  sara veramente importante',
#   'positivo'),
#  ('estadio vaiaram dilma   hoje votaram nela ah oi  comassim producao ',
#   'positivo'),
#  ('nao gosto dilma tchau', 'neutro'),
#  (' ta  continua ai dilma   nao voto nela tudo bem', 'neutro'),
#  ('dilma rousseff logra  ciento en comicios  segun sondeo la presidenta brasiledilma rousseff  logro un   iftttcnifwo',
#   'neutro'),
#  ('nao creio q ainda gente dizendo q vai votar dilma segundo turno',
#   'negativo'),
#  ('galera nao votou aecio   vai votar dilma     hein  ', 'neutro'),
#  ('sorte hoje nao votei dilma    seadilmaganharosonibusvaoqueimar', 'neutro'),
#  ...]
