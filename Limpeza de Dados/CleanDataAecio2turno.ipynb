# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import csv
from bs4 import BeautifulSoup
import re
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()

# %%
dataset=pd.read_csv("Dados Treinamento/aecio_2turno_treinamento.txt",delimiter="\t",encoding='latin-1')

# %%
dataset['text']= dataset['text'].replace(r'http:\S+', '', regex=True).replace(r'www\S+', '', regex=True).replace(r'https:\S+', '', regex=True).replace(r'instagram\S+', '', regex=True).replace(r'j.mp\S+', '', regex=True).replace(r'bit.ly\S+','',regex=True).replace(r'@\S+','',regex=True).replace(r'\d+','',regex=True)

# %%
def removestopwords(texto):
    frases = []
   
    for palavras in texto:
        
        palavras = palavras.lower()
        palavras = palavras.replace('?',' ')
        palavras = palavras.replace('#','')
        palavras = palavras.replace('!',' ')
        palavras = palavras.replace('%',' ')
        palavras = palavras.replace('. ',' ')
        palavras = palavras.replace(')',' ')
        palavras = palavras.replace('(',' ')
        palavras = palavras.replace('-',' ')
        palavras = palavras.replace(',',' ')
        palavras = palavras.replace('/ ',' ')
        palavras = palavras.replace('*',' ')
        palavras = palavras.replace('=',' ')
        palavras = palavras.replace(':','')
        
        palavras = palavras.replace('r$',' ')
               
        palavras = palavras.replace('á','a')
        palavras = palavras.replace('à','a')
        palavras = palavras.replace('â','a')
        palavras = palavras.replace('ã','a')
        
        palavras = palavras.replace('é','e')
        palavras = palavras.replace('è','e')
        palavras = palavras.replace('ê','e')
        
        
        palavras = palavras.replace('í','i')
        palavras = palavras.replace('ì','i')
        palavras = palavras.replace('î','i')
                       
        palavras = palavras.replace('ó','o')
        palavras = palavras.replace('ò','o')
        palavras = palavras.replace('ô','o')
        palavras = palavras.replace('õ','o')
        
        palavras = palavras.replace('ú','u')
        palavras = palavras.replace('ù','u')
        palavras = palavras.replace('û','u')
               
        palavras = palavras.replace('ç','c')
              
        frases.append(palavras)
                                    
        
    return frases

# %%
clean = removestopwords(dataset['text'])

# %%
dataset['text'] = clean

# %%
dataset.to_csv('Aecio_2turno_limpo.txt', sep='\t', mode='a',index=False)

# %%
dataset
# Out:
#               username              date  retweets  favorites  \
# 0             a4server  26/10/2014 21:59         0          0
# 1           FELIZ_2015  26/10/2014 21:59         0          0
# 2           pr_jrafael  26/10/2014 21:59         0          0
# 3           OslecMac74  26/10/2014 21:59         0          0
# 4      MariaCarmemRibe  26/10/2014 21:59         0          0
# 5        larrympecavel  26/10/2014 21:59         0          0
# 6          RealRafinha  26/10/2014 21:59         0          0
# 7       winchestermind  26/10/2014 21:59         0          0
# 8         EwertonLuppo  26/10/2014 21:59         0          0
# 9        hudsonccoelho  26/10/2014 21:59         0          0
# 10          Groveaneed  26/10/2014 21:59         0          0
# 11     leandrooresende  26/10/2014 21:59         0          0
# 12         TelaAbsurda  26/10/2014 21:59         4          2
# 13         danilinhovs  26/10/2014 21:59         0          0
# 14             raqnisk  26/10/2014 21:59         0          0
# 6      a maior de todas as prioridades de dilma deve ...  NaN
# 7            voce e o melhor  espero voce daqui a  anos   NaN
# 8                             cade o  no twitter  sumiu   NaN
# 9                                                         NaN
# 10                             todos unidos pelo brasil   NaN
# 11                  n perdeu no nordeste e sim em minas   NaN
# 12      ripbrasil eu estou chateado com a reeleicao d...  NaN
# 13      parabens ao menos podemos sonhar com um pais ...  NaN
# 14     agora eh o  voltar com tudo pro senado  e o ps...  NaN
# 15       mas aonde esta aquele sorriso de cinismo  a ...  NaN
# 16     rt  triste irmaos brasileiros ter tomado essa ...  NaN
# 17        tucanos lamentam derrota de  nas eleicoes  ...  NaN
# 18                         rt  pic.twitter.com/nvjrqwmev  NaN
# 19                      lindo  tesao  bonito e gostosao   NaN
# 20      nao faria isso  nao depois de toda essa robal...  NaN
# 21      sim votei no aecio e vou vota dnovo de ele se...  NaN
# 22     parece que o aecio ta na frente e agora  rt  ...  NaN
# 23      e grande vitorioso das eleicoes lutar contra ...  NaN
# 24        prezados  pelo futuro dos meus filhos  sang...  NaN
# 25        se o brasil aceitar isso  esse sim sera fra...  NaN
# 26         tem que tomar providencias  ou nao sobrara...  NaN
# 27     brazil 's incumbent dilma rousseff headed for ...  NaN
# 28                                      rt  to eliminada  NaN
# 29                                       parabens aecio   NaN
# ...                                                  ...  ...
# 38610  quem conhece    confia ta todo mundo com a gen...  NaN
# 38611  a  passou mal no debate e precisou tomar um  p...  NaN
# 38612    ...  nao e corrupcao  e desmonte do patrimon...  NaN
# 38613   na cabeca apesar de voce amanha ha de ser out...  NaN
# 38614                                                     NaN
# 38615         parabens pelo debate de hoje  presidente    NaN
# 38616  urgente  da  nao informou nada sobre acusacao ...  NaN
# 38617   e por que seu primo  o quedo  leva a chave do...  NaN
# 38618   coloca o dado dolabella agressor de mulher no...  NaN
# 38619  rio times latest poll.. aecioneves  percent di...  NaN
# 38620        sou seu eleitor e logo opositor  vou cobrar  NaN
# 38621   aecioo vc e mudanca vc que vai muda esse bras...  NaN
# 38622  meu tuite sobre lula/collor so foi pra ressalt...  NaN
# 38623   da conta do recado e e o presidente da espera...  NaN
# 38624        qdo ela entrelacava as maos eu dizia aqu...  NaN
# 38625   a dilma nao diz nada a respeito do que o pt f...  NaN
# 38626  irmao de dilma foi 'assessor especial' de pref...  NaN
# 38627     oglobo.globo.com/opiniao/invest imento no p...  NaN
# 38628     o brasil quer se livrar desse governo o br...  NaN
# 38629  q rt   top pessoas populares    dilmabr    gra...  NaN
# 38630          pt ja era agora e a vez da mudanca  aecio  NaN
# 38631       e falta de carne comer somente ovo e prej...  NaN
# 38632  depois que o  apoiou o  ja teve o primeiro noc...  NaN
# 38633   caro candidato  tenho acompanhado os debates ...  NaN
# 38634                                   agorabrasilaecio  NaN
# 38635     foi sempre a opcao de    combater a verdade...  NaN
# 38636     primos irma   tio genro do padrasto  alface...  NaN
# 38637      e bom falar tambem que em  a dilma nao tin...  NaN
# 38638     isso sao  trilhoes tem certeza que nao tem ...  NaN
# 38639   bom  raciocinio para ela ja e complicado  dep...  NaN
#
#                                                 mentions  \
# 0      @AecioNeves @donincrenca @AdeusPetralhas @doni...
# 1                     @JornalOGlobo @dilmabr @AecioNeves
# 2                                            @AecioNeves
# 3                             @AecioNeves @TwitterBrasil
# 4                                            @AecioNeves
# 5                                            @AecioNeves
# 6                                            @AecioNeves
# 7                                            @AecioNeves
# 8                                            @AecioNeves
# 9      @naoaocomunismo @AecioPresida @marisascruz @Ae...
# 10                                           @AecioNeves
# 11                                           @AecioNeves
# 12                                  @Hialley @AecioNeves
# 13                                           @AecioNeves
# 14                                   @AecioNeves @Rede45
# 15                                  @diImabr @AecioNeves
# 16                                           @AecioNeves
# 17                                  @Estadao @AecioNeves
# 18                                           @AecioNeves
# 19                                           @AecioNeves
# 20                                           @AecioNeves
# 21                                           @AecioNeves
# 22                                           @AECIONEVES
# 23                                           @AecioNeves
# 24                @aloysio_nunes @AecioNeves @joseserra_
# 25                  @edgaarcia @PSDBnacional @AecioNeves
# 26     @2012Cacerolazo @RolendoG4ston @AnaLaura860 @A...
# 27                                                   NaN
# 28                                           @aecioneves
# 29                                           @AecioNeves
# ...                                                  ...
# 38610                                        @AecioNeves
# 38611                               @dilmabr @AecioNeves
# 38612                     @AecioNeves @neymarjr @Ronaldo
# 38613                                        @AecioNeves
# 38614             @turmadochapeu_ @mvpcastro @AecioNeves
# 38615                                        @AecioNeves
# 38616     @jornalnacional @RedeGlobo @Rede45 @AecioNeves
# 38617                                        @AecioNeves
# 38618                                        @AecioNeves
# 38619                                                NaN
# 38620                                        @AecioNeves
# 38621                                        @AecioNeves
# 38622                                        @AecioNeves
# 38623                                        @AecioNeves
# 38624  @somar61 @Bluesette22 @CongressoPodre @Dricunh...
# 38625                                        @AecioNeves
# 38626                                        @AecioNeves
# 38627                              @monaemik @AecioNeves
# 38628                                @Rede45 @AecioNeves
# 38629      @twirus_brasil @AecioNeves @analfabteo @_urgh
# 38630                        @FAXINANOPODER_ @AecioNeves
# 38631       @g1 @AecioNeves @dilmabr @silva_marina @VEJA
# 38632                        @SpiderAnderson @AecioNeves
# 38633                                        @AecioNeves
# 38634    @cmaclis @BR19752014 @RejaneLiberty @AecioNeves
# 38635    @fascutare @edwardluz @AecioNeves @silva_marina
# 38636                        @OGloboPolitica @AecioNeves
# 38637  @OGloboPolitica @Clement_Izard @AecioNeves @di...
# 38638          @marisascruz @AluisioEscritor @AecioNeves
# 38639                           @Pepez_Legal @AecioNeves
#
#                                                 hashtags        id  \
# 0                                                    NaN  5,27E+17
# 1                                                    NaN  5,27E+17
# 2                                                    NaN  5,27E+17
# 3                                                    NaN  5,27E+17
# 4                                                    NaN  5,27E+17
# 5                                                    NaN  5,27E+17
# 6                                                    NaN  5,27E+17
# 7                                                    NaN  5,27E+17
# 8                                                    NaN  5,27E+17
# 9                                                    NaN  5,27E+17
# 10                                                   NaN  5,27E+17
# 11                                                   NaN  5,27E+17
# 12                                  #RIPBrasil #chateado  5,27E+17
# 13                                                   NaN  5,27E+17
# 14                                        #PSDB #Br45sil  5,27E+17
# 15                                       #DilmaNovamente  5,27E+17
# 16                                                   NaN  5,27E+17
# 17                                                   NaN  5,27E+17
# 18                                                   NaN  5,27E+17
# 19                                                   NaN  5,27E+17
# 20                                            #RIPBrasil  5,27E+17
# 21                                                   NaN  5,27E+17
# 22                                                   NaN  5,27E+17
# 23                                                   NaN  5,27E+17
# 24                                            #petralhas  5,27E+17
# 25                                                   NaN  5,27E+17
# 26                                                   NaN  5,27E+17
# 27                             #Brazil #dilmarousseff #a  5,27E+17
# 28                                                   NaN  5,27E+17
# 29                                                   NaN  5,27E+17
# ...                                                  ...       ...
# 38610                                #AgoraBrasilAecio45  5,23E+17
# 38611                                       #DebateNoSBT  5,23E+17
# 38612                                       #DebateNoSBT  5,23E+17
# 38613                                                NaN  5,23E+17
# 38614                                                NaN  5,23E+17
# 38615                                                NaN  5,23E+17
# 38616                                      #CPIPetrobras  5,23E+17
# 38617                                                NaN  5,23E+17
# 38618                                     #VouComDilma13  5,23E+17
# 38619  #AecioNeves #DilmaRousseff #MarketLiberal #Int...  5,23E+17
# 38620                                                NaN  5,23E+17
# 38621                                                NaN  5,23E+17
# 38622                                                NaN  5,23E+17
# 38623                                      #AgoraBrasilA  5,23E+17
# 38624                                                NaN  5,23E+17
# 38625                                                NaN  5,23E+17
# 38626                    #mudabrasil #AgoraBrasilAecio45  5,23E+17
# 38627                                                NaN  5,23E+17
# 38628                                                NaN  5,23E+17
# 38629                                                NaN  5,23E+17
# 38630                                                NaN  5,23E+17
# 38631                                                NaN  5,23E+17
# 38632                         #Aecio45 #AecioPelaMudanca  5,23E+17
# 38633                                                NaN  5,23E+17
# 38634                                #AgoraBrasilAecio45  5,23E+17
# 38635                                                NaN  5,23E+17
# 38636                                                NaN  5,23E+17
# 38637                                                NaN  5,23E+17
# 38638                                                NaN  5,23E+17
# 38639                            #ForaDilmaeLeveOPTJunto  5,23E+17
#
#                                                permalink
# 0      https://twitter.com/a4server/status/5265236628...
# 1      https://twitter.com/FELIZ_2015/status/52652364...
# 2      https://twitter.com/pr_jrafael/status/52652363...
# 3      https://twitter.com/OslecMac74/status/52652363...
# 4      https://twitter.com/MariaCarmemRibe/status/526...
# 5      https://twitter.com/larrympecavel/status/52652...
# 6      https://twitter.com/RealRafinha/status/5265236...
