# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import csv
from bs4 import BeautifulSoup
import re
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
import nltk    
from nltk import tokenize

# %%
dataset=pd.read_csv("Dilma_1turno_limpo.txt",delimiter="\t",encoding='latin-1')

# %%
dataset['text']= dataset['text'].replace(r'http:\S+', '', regex=True).replace(r'www\S+', '', regex=True).replace(r'https:\S+', '', regex=True).replace(r'instagram\S+', '', regex=True).replace(r'j.mp\S+', '', regex=True).replace(r'bit.ly\S+','',regex=True).replace(r'@\S+','',regex=True).replace(r'\d+','',regex=True)

# %%
def removestopwords(texto):
    frases = []
   
    for palavras in texto:
        
        palavras = palavras.lower()
        palavras = palavras.replace('?',' ')
        palavras = palavras.replace('#','')
        palavras = palavras.replace('!',' ')
        palavras = palavras.replace('%',' ')
        palavras = palavras.replace('. ',' ')
        palavras = palavras.replace(')',' ')
        palavras = palavras.replace('(',' ')
        palavras = palavras.replace('-',' ')
        palavras = palavras.replace(',',' ')
        palavras = palavras.replace('/ ',' ')
        palavras = palavras.replace('*',' ')
        palavras = palavras.replace('=',' ')
        palavras = palavras.replace(':','')
        
        palavras = palavras.replace('r$',' ')
               
        palavras = palavras.replace('á','a')
        palavras = palavras.replace('à','a')
        palavras = palavras.replace('â','a')
        palavras = palavras.replace('ã','a')
        
        palavras = palavras.replace('é','e')
        palavras = palavras.replace('è','e')
        palavras = palavras.replace('ê','e')
        
        
        palavras = palavras.replace('í','i')
        palavras = palavras.replace('ì','i')
        palavras = palavras.replace('î','i')
                       
        palavras = palavras.replace('ó','o')
        palavras = palavras.replace('ò','o')
        palavras = palavras.replace('ô','o')
        palavras = palavras.replace('õ','o')
        
        palavras = palavras.replace('ú','u')
        palavras = palavras.replace('ù','u')
        palavras = palavras.replace('û','u')
               
        palavras = palavras.replace('ç','c')
              
        frases.append(palavras)
                                    
        
    return frases

# %%
clean = removestopwords(dataset['text'])

# %%
dataset['text'] = clean

# %%
dataset.to_csv('Dilma_1turno_limpo.txt', sep='\t', mode='a',index=False)

# %%
dataset1=pd.read_csv("Dilma_1turno_limpo.txt",delimiter="\t",encoding='latin-1')

# %%
dataset1
# Out:
#               username              date  retweets  favorites  \
# 0            RaulDudek  05/10/2014 19:59         0          0
# 1            wtshatboy  05/10/2014 19:59         1          0
# 2              RNemitz  05/10/2014 19:59         0          2
# 3        GeiciSantiago  05/10/2014 19:59         0          0
# 4         michaelserra  05/10/2014 19:59         0          0
# 5         potterhalder  05/10/2014 19:59         1          0
# 6          DonaErvilha  05/10/2014 19:59         0          0
# 7            afe_marco  05/10/2014 19:59         0          0
# 8       FCLorenaBuerii  05/10/2014 19:59         0          1
# 9          crazyalicew  05/10/2014 19:59         0          1
# 10       Feliz_por_Dan  05/10/2014 19:59         0          0
# 11       yashagallazzi  05/10/2014 19:59       106         67
# 12     isabellyborgesm  05/10/2014 19:59         0          0
# 13        gabiscoelho_  05/10/2014 19:59         0          0
# 14         giopessoa11  05/10/2014 19:59         0          0
# 7                                       dilma e aecio af  NaN
# 8      pobre...so pensa em bolsa familia so isso q di...  NaN
# 9      essa coisa dos nordestino votar na dilma so po...  NaN
# 10                         Â° turno dilma e aecio neves   NaN
# 11     aecio ta so   atras de dilma  vamos virar isso...  NaN
# 12     eu falei que ia dar aecio cheira po e dilma no...  NaN
# 13     a unica coisa que n queria era alckmin governa...  NaN
# 14     affs depois o povo mete o pau na dilma e agora...  NaN
# 15     aaaargh que odio desse povo brasileiro  faz pr...  NaN
# 16     confirmado aecio neves x dilma no segundo turn...  NaN
# 17               a dilma ganhou por causa dos pobres ...  NaN
# 18                    turno confirmado    dilma x aecio.  NaN
# 19                       dilma perde no segundo turno...  NaN
# 20            aecio e dilma segundo turno  aecioconfirma  NaN
# 21     toma porra to revoltada com esse pais retardad...  NaN
# 22     antigamente so filhos de ricos se formavam  gr...  NaN
# 23                               e dilma e dilma e dilma  NaN
# 24       a dilma pegou um pais ja estabilizado no sis...  NaN
# 25        tanto faz aecio ou dilma nenhum ai prestar msm  NaN
# 26            partiu segundo turno    dilma vs aecio      NaN
# 27     dilma e aecio estao garantidos no segundo turn...  NaN
# 28                           Â¤ turno aecio e dilma puts  NaN
# 29      verdade vamos ver quem marina e os outros vao...  NaN
# ...                                                  ...  ...
# 44726  eu quero e saber quem via pro Âº turno com a d...  NaN
# 44727  sacanagem  estao segurando os resultados presi...  NaN
# 44728  imagens de dilma   marina e aecio na infancia ...  NaN
# 44729    lu ou dilma as melhores opcoes marina uma pl...  NaN
# 44730  nossa tirar a dilma pra por o aecio  vao se foder  NaN
# 44731     quero aecio no segundo turno com a mamae dilma  NaN
# 44732     lula ' dilma quer debater corrupcao com aec...  NaN
# 44733  internautas declaram apoio e dilma e marina sa...  NaN
# 44734  sou do nordeste e nao votei na dilma e nem nos...  NaN
# 44735  voce nao querem aecio  nao querem dilma   nao ...  NaN
# 44736  internautas declaram apoio  e dilma e marina s...  NaN
# 44737                       secao  dilma  marina  aecio   NaN
# 44738  a tag marinabrasil estava disparado na frente ...  NaN
# 44739  sobre morgar com um boyzinho pq ele votou em d...  NaN
# 44740             caindo a dilma hoje nada mais importa   NaN
# 44741           apuracao dilma  aecio  marina  ben  cpm   NaN
# 44742  caracas pelo menos na secao que eu trabalhei d...  NaN
# 44743  dilma   minha querida  se voce for eleita me a...  NaN
# 44744                                 dilma tu nao ganha  NaN
# 44745   m.facebook.com/l.php u http  a f f Â
#  hahahah...  NaN
# 44746    olha  acho q e uma mistura dos dois > gananc...  NaN
# 44747  eu so to vendo papel com aecio dando de lavada...  NaN
# 44748  reclama que o pdsb ta muito tempo no poder em ...  NaN
# 44749   so me resta rezar para que dilma meta o pe da...  NaN
# 44750  psdb saudado pt vaiado e o porque de dilma a f...  NaN
# 44751  se o aecio ganhar nao tem nada errado  agora s...  NaN
# 44752   entre dilma   marina e aecio  vou pela primei...  NaN
# 44753  causo de que ela nao gosta da dilma heheh rt  ...  NaN
# 44754          caramba  imagina se a dilma for reeleita   NaN
# 44755  ate agora tentando entender aquelas pessoas qu...  NaN
#
#                             mentions                          hashtags  \
# 0                                NaN                    #AECIOdeVirada
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# 5                                NaN                               NaN
# 6                        @cbonlinedf                               NaN
# 7                                NaN                               NaN
# 8                                NaN                               NaN
# 9                                NaN                               NaN
# 10                               NaN                               NaN
# 11                               NaN                               NaN
# 12                               NaN                               NaN
# 13                               NaN                               NaN
# 14                               NaN                       #que #merda
# 15                               NaN                               NaN
# 16                               NaN                               NaN
# 17                               NaN                               NaN
# 18                               NaN                               NaN
# 19                               NaN                               NaN
# 20                               NaN                  #45AecioConfirma
# 21                               NaN                               NaN
# 22                               NaN                               NaN
# 23                               NaN                               NaN
# 24     @MathShadows @douradocarvalho                               NaN
# 25                               NaN                               NaN
# 26                               NaN                               NaN
# 27                               NaN                               NaN
# 28                               NaN                               NaN
# 29                         @IzaNina_                               NaN
# ...                              ...                               ...
# 44726                            NaN                               NaN
# 44727                            NaN                               NaN
# 44728                            NaN                               NaN
# 44729          @joao_gui_ @viniperes                               NaN
# 44730                            NaN                               NaN
# 44731                            NaN                               NaN
# 44732              @UOLNoticias @UOL                               NaN
# 44733                            NaN                               NaN
# 44734                            NaN                               NaN
# 44735                            NaN                               NaN
# 44736                            NaN                               NaN
# 44737                            NaN                               NaN
# 44738                            NaN  #MarinaBrasil40 #EuVoteiMarina40
# 44739                            NaN                               NaN
# 44740                            NaN                               NaN
# 44741                            NaN                               NaN
# 44742                            NaN                               NaN
# 44743                            NaN                               NaN
# 44744                            NaN                               NaN
# 44745                            NaN                               NaN
# 44746          @j011yr0g3r @biacall8                 #Dilma13PraVencer
# 44747                            NaN                      #medo #pavor
# 44748                            NaN                               NaN
# 44749                 @AndreMOficial                               NaN
# 44750                            NaN                               NaN
# 44751                            NaN                               NaN
# 44752                       @Fall_10                               NaN
# 44753  @Leo_Underscore @laescosteguy                               NaN
# 44754                            NaN                               NaN
# 44755                            NaN                               NaN
#
#              id                                          permalink
# 0      5,19E+17  https://twitter.com/RaulDudek/status/518898425...
# 1      5,19E+17  https://twitter.com/wtshatboy/status/518898424...
# 2      5,19E+17  https://twitter.com/RNemitz/status/51889842442...
# 3      5,19E+17  https://twitter.com/GeiciSantiago/status/51889...
# 4      5,19E+17  https://twitter.com/michaelserra/status/518898...
# 5      5,19E+17  https://twitter.com/potterhalder/status/518898...
# 6      5,19E+17  https://twitter.com/DonaErvilha/status/5188984...
# 7      5,19E+17  https://twitter.com/afe_marco/status/518898423...
# 8      5,19E+17  https://twitter.com/FCLorenaBuerii/status/5188...
# 9      5,19E+17  https://twitter.com/crazyalicew/status/5188984...
# 10     5,19E+17  https://twitter.com/Feliz_por_Dan/status/51889...
# 11     5,19E+17  https://twitter.com/yashagallazzi/status/51889...
# 12     5,19E+17  https://twitter.com/isabellyborgesm/status/518...
# 13     5,19E+17  https://twitter.com/gabiscoelho_/status/518898...
# 14     5,19E+17  https://twitter.com/giopessoa11/status/5188984...
# 15     5,19E+17  https://twitter.com/Darlinglax_/status/5188984...
# 16     5,19E+17  https://twitter.com/ismacedo_/status/518898421...
# 17     5,19E+17  https://twitter.com/NoPocketBP/status/51889842...
