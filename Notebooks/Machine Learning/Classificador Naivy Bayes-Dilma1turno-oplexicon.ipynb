# %%
from textblob import TextBlob
import pandas as pd  
import numpy as np
from textblob.classifiers import NaiveBayesClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import sklearn
from sklearn import metrics
from sklearn import naive_bayes
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score
import numpy as np # linear algebra
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
dilma1turno=pd.read_csv("/home/bruno/Documents/artigo/R/Dilma_oplexiconLimpo.txt",delimiter="\t",encoding='latin-1')

# %%
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1

# %%
import csv
from wordcloud import WordCloud


#read first column of csv file to string of words seperated
#by tab

your_list = []
with open('words.csv', 'rb') as f:
    reader = csv.reader(f)
    your_list = '\t'.join([i[0] for i in reader])


# Generate a word cloud image
wordcloud = WordCloud().generate(your_list)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(your_list)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-8-1be9f6e45cd9> in <module>()
#       9 with open('/home/bruno/Documents/artigo/R/Dilma_oplexiconLimpo.txt', 'rb') as f:
#      10     reader = csv.reader(f)
# ---> 11     your_list = '\t'.join([i[0] for i in reader])
#      12
#      13
#
# <ipython-input-8-1be9f6e45cd9> in <listcomp>(.0)
#       9 with open('/home/bruno/Documents/artigo/R/Dilma_oplexiconLimpo.txt', 'rb') as f:
#      10     reader = csv.reader(f)
# ---> 11     your_list = '\t'.join([i[0] for i in reader])
#      12
#      13
#
# Error: iterator should return strings, not bytes (did you open the file in text mode?)

# %%
dilma1turno[['username','date','text','sentiment_textblob','sentiment_oplexicon']].head(10)
# Out:
#           username              date  \
# 0        RaulDudek  05/10/2014 19:59
# 1          RNemitz  05/10/2014 19:59
# 2     potterhalder  05/10/2014 19:59
# 3      crazyalicew  05/10/2014 19:59
# 4     gabiscoelho_  05/10/2014 19:59
# 5      Darlinglax_  05/10/2014 19:59
# 6  BeatriceZaretti  05/10/2014 19:59
# 7    maathlinhares  05/10/2014 19:59
# 8   AninhaBlockPop  05/10/2014 19:59
# 9        Pauleraa_  05/10/2014 19:59
#
#                                                 text sentiment_textblob  \
# 0  geraldo alckmin reeleito governador sao paulo ...           negativo
# 1  dilma rousseff pt aecio neves psdb vao disputa...             neutro
# 2  voces idolatrando aecio minimo nao sabem nada ...           negativo
# 3  coisa nordestino votar dilma so causa bolsa fa...           positivo
# 4  unica coisa n queria alckmin governador dilma ...             neutro
# 5  aaaargh odio desse povo brasileiro faz protest...           negativo
# 6  toma porra to revoltada pais retardado q vota ...           negativo
# 7  dilma pegou pais ja estabilizado sistema pt an...           positivo
# 8  verdade vamos ver marina outros vao apoiar dil...             neutro
# 9        dilma aecio segundo turno voces sao otarios             neutro
#
#   sentiment_oplexicon
# 0            positivo
# 1            negativo
# 2              neutro
# 3              neutro
# 4            positivo
# 5            negativo
# 6            positivo
# 7            positivo
# 8              neutro
# 9            positivo

# %%
subset = dilma1turno[['text', 'sentimento']]
tuples_dilma_1turno = [tuple(x) for x in subset.values]

# %%
vectorizer = TfidfVectorizer(use_idf=True,
                             lowercase=True, strip_accents='ascii', stop_words=None)

# %%
Y = dilma1turno['sentimento']

# %%
X = vectorizer.fit_transform(dilma1turno['text'])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

# %%
clf = naive_bayes.MultinomialNB()

# %%
clf.fit(X_train,Y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
dilma1turno=pd.read_csv("/home/bruno/Documents/artigo/R/Sentiment/class_hand.csv",delimiter=",",encoding='latin-1')

# %%
numpy_matrix = dilma1turno['Text'].as_matrix()

# %%
numpy_matrix
# Out:
# numpy.ndarray

# %%
tweet = np.array(['Eu odeio a Dilma'])

# %%
tweet_vector = vectorizer.transform(numpy_matrix)

# %%
tweet_vector
# Out:
# <2999x11191 sparse matrix of type '<class 'numpy.float64'>'
# 	with 30761 stored elements in Compressed Sparse Row format>

# %%
print(clf.predict(tweet_vector[1]))
# Out:
# ['neutro']

# %%
for i in range(2999):
    dilma1turno['free'][i] = clf.predict(tweet_vector[i])

# %%
dilma1turno
# Out:
#                                                    Text Sentiment        free
# 0     voces idolatrando aecio minimo nao sabem nada ...   Neutral  [negativo]
# 1     coisa nordestino votar dilma so causa bolsa fa...   Neutral    [neutro]
# 2     verdade vamos ver marina outros vao apoiar dil...   Neutral  [positivo]
# 3                   dilma vai ganhar gente infelizmente   Neutral    [neutro]
# 4     muy buena votacion del democrata neves solo di...   Neutral    [neutro]
# 5     voces votaram dilma esperando faca algo bom va...   Neutral  [negativo]
# 6     alguem conhece alguem algo ganhar eleicao aeci...   Neutral  [negativo]
# 7                  gente dilma ganhar aecio cu rolaaaaa   Neutral    [neutro]
# 8     dilma aecio turno ai cu dilma nao pode ganhar ...   Neutral    [neutro]
# 9          aecio ganhar ferrou tudo prefiro x tia dilma   Neutral  [negativo]
# 10    tambem ja viu escolas alguns lugares sao enfim...   Neutral    [neutro]
# 11         chupaaaa dilma trouxa aecio vai ganhar uhull   Neutral    [neutro]
# 12    aecio ganhar ate marina serve dilma filha cape...   Neutral    [neutro]
# 13    en un resultado inesperado dilma y aecio neves...   Neutral    [neutro]
# 14    governo dilma passou longe perfeito outros can...   Neutral  [negativo]
# 15    sei la vcs nao acha estranho dilma ajudar pais...   Neutral    [neutro]
# 16    aecio ganhar porra vcs votarem dilma brasil va...   Neutral  [negativo]
# 17    nao sei eh pior aecio dilma brasil excelente c...   Neutral    [neutro]
# 18            aecio q ganhar anos dilma deus meee livre   Neutral    [neutro]
# 19    serio gente mineira to falando dilma aecio fiq...   Neutral    [neutro]
# 20                          dilma nao pode ganhar serio   Neutral    [neutro]
# 21    prefiro marina aecio tbm parece ser pior dilma...   Neutral  [negativo]
# 22    votou agora luciana pra apoiar sabia ia ter se...   Neutral  [negativo]
# 23    contar q governo dilma deixou inflacao complet...   Neutral    [neutro]
# 24    acho q ate bom aecio ganhar vcs perceberem q d...   Neutral    [neutro]
# 25    serio dilma vai ganhar bosta novo to acompanha...   Neutral    [neutro]
# 26    serio alguem ficou surpreso dilma aecio segund...   Neutral    [neutro]
# 27    confirmado dilma aecio vao pro segundo turno d...   Neutral  [negativo]
# 28    la campaanti dilma fue bestial aprovecharon gr...   Neutral    [neutro]
# 29       vai social vota dilma vai lado economico aecio   Neutral    [neutro]
# ...                                                 ...       ...         ...
# 2969  tudo pra chegar hoje votar dilma tudo pra cheg...  Negative  [negativo]
# 2970  tendo dito digo votei eduardo jorge agora meno...  Negative  [negativo]
# 2971  vcs acham ta ruim dilma elejam aecio pra ver m...  Negative  [negativo]
# 2972  ja to sofrendo segundo turno to frustrada igua...  Negative  [negativo]
# 2973  deixaram d votar dilma p votar aecio zzzzzzzz ...  Negative  [negativo]
# 2974  estados nordeste dilma vai ganhando povo conse...  Negative  [negativo]
# 2975  gente horrivel saber pais so vai retroceder di...  Negative  [negativo]
# 2976  dilma aecio turno vao disputar pra ver vai fud...  Negative  [negativo]
# 2977                 vai la votar dilma ser otario novo  Negative  [negativo]
# 2978  pra defender dilma ser sustentado bolsa famili...  Negative  [negativo]
# 2979  quer mudanca ne entao porra deu pra votar puta...  Negative  [negativo]
# 2980                                    dilma ruim ruim  Negative  [negativo]
# 2981  nao votei dilma nao devo votar nela turno tb n...  Negative  [negativo]
# 2982  kd gigante q acordado dormiu d novo vagabundo ...  Negative  [negativo]
# 2983  povo brasileiro memoria curta so pode ano pass...  Negative  [negativo]
# 2984              pior votar tiririca votar dilma aecio  Negative  [negativo]
# 2985        dilma aecio segundo turno brasil ta perdido  Negative  [negativo]
# 2986               dilma marina carioca muuuuuito burro  Negative  [negativo]
# 2987                          dilma aercio nao sei pior  Negative  [negativo]
# 2988                       antes disso dilma pra salvar  Negative  [negativo]
# 2989  alckmin reeleito sp dilma brasil continua tudo...  Negative  [negativo]
# 2990                  dilma x aecio mortal kombaaaaaaat  Negative  [negativo]
# 2991  dilma ficou terceiro lugar aqui regiao obrigad...  Negative  [negativo]
# 2992      votarei nulo pior hipoteses dilma nunca aecio  Negative  [negativo]
# 2993  saldo bancario dilma deve estar negativo agora...  Negative  [negativo]
# 2994  vamos compartilhar absurdo dilma dessa vez sua...  Negative  [negativo]
# 2995              familia inteira votou dilma vao foder  Negative  [negativo]
# 2996  muita tristeza coracao vou votar dilma segundo...  Negative  [negativo]
# 2997  ai vc pensa q votou dilma burro gente votou aecio  Negative  [negativo]
# 2998  vao la protestar agora votam dilma tomem vergo...  Negative  [negativo]
#
# [2999 rows x 3 columns]

# %%
clf.score(X_train,Y_train)
# Out:
# 0.8816568047337278

# %%
dilma1turno.to_csv('/home/bruno/Documents/artigo/R/free_hands.csv', sep='\t', mode='a',index=False)
