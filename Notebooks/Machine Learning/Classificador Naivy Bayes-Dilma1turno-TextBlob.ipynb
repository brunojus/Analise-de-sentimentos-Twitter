# %%
from textblob import TextBlob
import pandas as pd  
import numpy as np
from textblob.classifiers import NaiveBayesClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import sklearn
from sklearn import metrics
from sklearn import naive_bayes
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score

# %%
dilma1turno=pd.read_csv("/home/bruno/Documents/artigo/R/Dilma_oplexiconLimpo.csv",delimiter="\t",encoding='latin-1')

# %%
subset = dilma1turno[['text', 'sentiment.x']]
tuples_dilma_1turno = [tuple(x) for x in subset.values]

# %%
dilma1turno
# Out:
#               username              date  retweets  favorites  \
# 0            RaulDudek  05/10/2014 19:59         0          0
# 1              RNemitz  05/10/2014 19:59         0          2
# 2         potterhalder  05/10/2014 19:59         1          0
# 3          crazyalicew  05/10/2014 19:59         0          1
# 4         gabiscoelho_  05/10/2014 19:59         0          0
# 5          Darlinglax_  05/10/2014 19:59         1          1
# 6      BeatriceZaretti  05/10/2014 19:59         0          0
# 7        maathlinhares  05/10/2014 19:59         0          0
# 8       AninhaBlockPop  05/10/2014 19:59         0          0
# 9            Pauleraa_  05/10/2014 19:59         0          0
# 10            zenrdaya  05/10/2014 19:59         0          0
# 11     Fernandocamorim  05/10/2014 19:59         0          0
# 12       MarianaZanoni  05/10/2014 19:59         0          0
# 13            sejehomi  05/10/2014 19:59         0          0
# 14      fabiomarceloap  05/10/2014 19:59         0          0
# 15          amandasep_  05/10/2014 19:59         0          0
# 16      MarceloRiveraO  05/10/2014 19:59         2          0
# 17          Lt_lycurgo  05/10/2014 19:59         0          0
# 18             _juniu_  05/10/2014 19:59         0          0
# 19          Maxanguana  05/10/2014 19:59         2          1
# 20      jdeandradeneto  05/10/2014 19:59         0          0
# 21         luanaemaike  05/10/2014 19:59         0          1
# 22       dileywildfire  05/10/2014 19:59         1          0
# 23          maricostta  05/10/2014 19:59         0          0
# 24          _indmorais  05/10/2014 19:59         1          1
# 25           1996sardi  05/10/2014 19:59         0          0
# 26         heisenmberg  05/10/2014 19:59         1          0
# 27     jornalismonaweb  05/10/2014 19:59         4          0
# 28           tabomcaio  05/10/2014 19:59         0          0
# 29               rdzrx  05/10/2014 19:59         0          0
# ...                ...               ...       ...        ...
# 45037    RaphaelDonida  05/10/2014 18:55         0          0
# 45038    carlisezbueno  05/10/2014 18:55         0          0
# 45039       Aglailsonn  05/10/2014 18:55         3          2
# 45040          M7theus  05/10/2014 18:55         0          0
# 45041       daalelucas  05/10/2014 18:55         0          0
# 45042        luisbutti  05/10/2014 18:55         0          0
# 45043   KimberllyCosta  05/10/2014 18:55         0          1
# 45044          rafavnt  05/10/2014 18:55         0          0
# 45045          whzliam  05/10/2014 18:55         0          0
# 45046     magalhaess95  05/10/2014 18:55         3          1
# 45047    dressaeulalia  05/10/2014 18:55         0          1
# 45048          itsgabs  05/10/2014 18:55         4          2
# 45049      jonaaninhas  05/10/2014 18:55         1          1
# 45050       FelipeanBh  05/10/2014 18:55         0          0
# 45051       oalanferro  05/10/2014 18:55         0          0
# 45052         MudaMais  05/10/2014 18:54        10          7
# 45053         Pireliss  05/10/2014 18:54         0          1
# 45054        mabyleite  05/10/2014 18:54         0          0
# 45055   lucaxdamasceno  05/10/2014 18:54         0          0
# 45056      annaluizaC_  05/10/2014 18:54         0          0
# 45057        Porra_my1  05/10/2014 18:54         8          3
# 45058    Indispensavel  05/10/2014 18:54         0          0
# 45059     changedtome_  05/10/2014 18:54         0          1
# 45060         Jbiel21S  05/10/2014 18:54         0          0
# 45061    ultimosegundo  05/10/2014 18:54         4          1
# 45062         MathCRF_  05/10/2014 18:54         1          0
# 45063    ultimosegundo  05/10/2014 18:54         1          3
# 45064          ItsNiiv  05/10/2014 18:54         0          0
# 45065  marcioeliasreis  05/10/2014 18:54         0          0
# 45066        ceesinhha  05/10/2014 18:54         1          2
#
#                                                     text  geo  \
# 0      geraldo alckmin reeleito governador sao paulo ...  NaN
# 1      dilma rousseff pt aecio neves psdb vao disputa...  NaN
# 2      voces idolatrando aecio minimo nao sabem nada ...  NaN
# 3      coisa nordestino votar dilma so causa bolsa fa...  NaN
# 4      unica coisa n queria alckmin governador dilma ...  NaN
# 5      aaaargh odio desse povo brasileiro faz protest...  NaN
# 6      toma porra to revoltada pais retardado q vota ...  NaN
# 7      dilma pegou pais ja estabilizado sistema pt an...  NaN
# 8      verdade vamos ver marina outros vao apoiar dil...  NaN
# 9            dilma aecio segundo turno voces sao otarios  NaN
# 10     culpa nao dilma vc trouxa ir la protesto falar...  NaN
# 11     mae mae petista feio ta querendo cumer mae bua...  NaN
# 12                  falou vai votar dilma ancia d vomito  NaN
# 13     acredito q eleitores marina tb vao pra dilma s...  NaN
# 14                      muda brasil dilma barbudo safado  NaN
# 15                   dilma vai ganhar gente infelizmente  NaN
# 16     muy buena votacion del democrata neves solo di...  NaN
# 17     visto infelizmente vou ter votar dilma segundo...  NaN
# 18     hrs dilma ganhar pq roubado ganhar apoio mega ...  NaN
# 19             dilma nao menos aecio nao eita povo lerdo  NaN
# 20     dilma jair pedro protesto ja nao ninguem joao ...  NaN
# 21     tambem nao recebo bolsa familia deixem votar d...  NaN
# 22     voces votaram dilma esperando faca algo bom va...  NaN
# 23     rt so dica dilma cair servidor cai tambem viu ...  NaN
# 24     tbm n leq aecio ganhar acabou pais esperanca p...  NaN
# 25     vou votar nulo segundo turno recuso votar dilm...  NaN
# 26     povo pra rua protestar meteu pau dilma pra hoj...  NaN
# 27          definido dilma aecio votos vao segundo turno  NaN
# 28     alguem conhece alguem algo ganhar eleicao aeci...  NaN
# 29                  gente dilma ganhar aecio cu rolaaaaa  NaN
# ...                                                  ...  ...
# 45037  dilma vai cair segundo turno razoes diz ricard...  NaN
# 45038   vai tomar cu vcs q votaram dilma gigante acordou  NaN
# 45039  vejo alguns estado pt vai pro turno existe raz...  NaN
# 45040  cara fico puto nego tava ano passado nesse ano...  NaN
# 45041  woow euvoteimarina ta tts brasil seguido tag d...  NaN
# 45042     ha diga vai ser ministro esportes dilma vencer  NaN
# 45043                       coisa pior dilma coisa aecio  NaN
# 45044  rt dilma vai levar eleicao nao sabe perder vai...  NaN
# 45045  dilma ganhar prova povo brasileiro bicho otari...  NaN
# 45046  adiantou fazerem todo chachos manifestacoes ve...  NaN
# 45047  dilma ganhar preciso fazer cultura fronteiras ...  NaN
# 45048  voces falam sobre manifestacoes dilma etc nao ...  NaN
# 45049         povo votou dilma medo perder bolsa miseria  NaN
# 45050  todos papeis vejo aecio ta frente ai hora voto...  NaN
# 45051  interssante dilma ganhar droga d resto governo...  NaN
# 45052  voce sabia dilma propostas melhorar ensino med...  NaN
# 45053                  band ta fudendo dilma bonito hein  NaN
# 45054  engracado vcs acusarem felipe xenofobia sao vo...  NaN
# 45055  tadinha dilma segundo turno vai perder lavada ...  NaN
# 45056       ia tirar urna pra ninguem sessao votar dilma  NaN
# 45057         dilma reeleita brasileiros sao tudo otario  NaN
# 45058   independente pro segundo turno dilma unir contra  NaN
# 45059                    tirar dilma pra aecio vao foder  NaN
# 45060  lula dilma quer debater corrupcao aecio uolbhd...  NaN
# 45061  internautas declaram apoio dilma marina sao ci...  NaN
# 45062  nordeste nao votei dilma sarneys chupa socieda...  NaN
# 45063  internautas declaram apoio dilma marina sao ci...  NaN
# 45064  dilma querida voce eleita ajuda ajudar porque ...  NaN
# 45065  psdb saudado pt vaiado porque dilma frente nao...  NaN
# 45066  aecio ganhar nao nada errado agora dilma ganha...  NaN
#
#                             mentions                            hashtags  \
# 0                                NaN                      #AECIOdeVirada
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
# 6                                NaN                                 NaN
# 7      @MathShadows @douradocarvalho                                 NaN
# 8                          @IzaNina_                                 NaN
# 9                                NaN                                 NaN
# 10                               NaN                                 NaN
# 11                      @marcopoliti                                 NaN
# 12                               NaN                                 NaN
# 13                        @dandannno                                 NaN
# 14                               NaN                                 NaN
# 15                               NaN                                 NaN
# 16                               NaN                                 NaN
# 17                               NaN                                 NaN
# 18                               NaN         #Dilma #Protesto #FORADILMA
# 19                               NaN                                  #A
# 20                      @JHF_Oficial                                 NaN
# 21                         @Luuanexx                                 NaN
# 22                               NaN                                 NaN
# 23                    @erikavgoulart                                 NaN
# 24                    @andrezzaindia                                 NaN
# 25                               NaN                                 NaN
# 26                               NaN                                 NaN
# 27                               NaN                                 NaN
# 28      @humberto_silva @guttolipaes                                 NaN
# 29                               NaN                                 NaN
# ...                              ...                                 ...
# 45037                            NaN                                 NaN
# 45038                            NaN                                 NaN
# 45039                            NaN  #EuVoteiMarina40 #Dilma13PraVencer
# 45040                   @crlmachadoo                                 NaN
# 45041                            NaN                    #EuVoteiMarina40
# 45042               @AdalbertoDantas                                 NaN
# 45043                            NaN                                 NaN
# 45044                  @pecesiqueira                                 NaN
# 45045                            NaN                                 NaN
# 45046                            NaN                                 NaN
# 45047                            NaN                                 NaN
# 45048                            NaN                                 NaN
# 45049                            NaN                                 NaN
# 45050                    @felipeneto                                 NaN
# 45051                            NaN                                 NaN
# 45052                            NaN                   #Dilma13PraVencer
# 45053                            NaN                                 NaN
# 45054                            NaN                                 NaN
# 45055                            NaN                                 NaN
# 45056                            NaN                                 NaN
# 45057                            NaN                                 NaN
# 45058                            NaN                                 NaN
# 45059                            NaN                                 NaN
# 45060              @UOLNoticias @UOL                                 NaN
# 45061                            NaN                                 NaN
# 45062                            NaN                                 NaN
# 45063                            NaN                                 NaN
# 45064                            NaN                                 NaN
# 45065                            NaN                                 NaN
# 45066                            NaN                                 NaN
#
#               id                                          permalink  \
# 0      5.19E+017  https://twitter.com/RaulDudek/status/518898425...
# 1      5.19E+017  https://twitter.com/RNemitz/status/51889842442...
# 2      5.19E+017  https://twitter.com/potterhalder/status/518898...
# 3      5.19E+017  https://twitter.com/crazyalicew/status/5188984...
# 4      5.19E+017  https://twitter.com/gabiscoelho_/status/518898...
# 5      5.19E+017  https://twitter.com/Darlinglax_/status/5188984...
# 6      5.19E+017  https://twitter.com/BeatriceZaretti/status/518...
# 7      5.19E+017  https://twitter.com/maathlinhares/status/51889...
# 8      5.19E+017  https://twitter.com/AninhaBlockPop/status/5188...
# 9      5.19E+017  https://twitter.com/Pauleraa_/status/518898418...
# 10     5.19E+017  https://twitter.com/zenrdaya/status/5188984177...
# 11     5.19E+017  https://twitter.com/Fernandocamorim/status/518...
# 12     5.19E+017  https://twitter.com/MarianaZanoni/status/51889...
# 13     5.19E+017  https://twitter.com/sejehomi/status/5188984165...
# 14     5.19E+017  https://twitter.com/fabiomarceloap/status/5188...
# 15     5.19E+017  https://twitter.com/amandasep_/status/51889841...
# 16     5.19E+017  https://twitter.com/MarceloRiveraO/status/5188...
# 17     5.19E+017  https://twitter.com/Lt_lycurgo/status/51889841...
# 18     5.19E+017  https://twitter.com/_juniu_/status/51889841142...
# 19     5.19E+017  https://twitter.com/Maxanguana/status/51889841...
# 20     5.19E+017  https://twitter.com/jdeandradeneto/status/5188...
# 21     5.19E+017  https://twitter.com/luanaemaike/status/5188984...
# 22     5.19E+017  https://twitter.com/dileywildfire/status/51889...
# 23     5.19E+017  https://twitter.com/maricostta/status/51889840...
# 24     5.19E+017  https://twitter.com/_indmorais/status/51889840...
# 25     5.19E+017  https://twitter.com/1996sardi/status/518898407...
# 26     5.19E+017  https://twitter.com/heisenmberg/status/5188984...
# 27     5.19E+017  https://twitter.com/jornalismonaweb/status/518...
# 28     5.19E+017  https://twitter.com/tabomcaio/status/518898404...
# 29     5.19E+017  https://twitter.com/rdzrx/status/5188984034521...
# ...          ...                                                ...
# 45037  5.19E+017  https://twitter.com/RaphaelDonida/status/51888...
# 45038  5.19E+017  https://twitter.com/carlisezbueno/status/51888...
# 45039  5.19E+017  https://twitter.com/Aglailsonn/status/51888220...
# 45040  5.19E+017  https://twitter.com/M7theus/status/51888218928...
# 45041  5.19E+017  https://twitter.com/daalelucas/status/51888217...
# 45042  5.19E+017  https://twitter.com/luisbutti/status/518882164...
# 45043  5.19E+017  https://twitter.com/KimberllyCosta/status/5188...
# 45044  5.19E+017  https://twitter.com/rafavnt/status/51888214900...
# 45045  5.19E+017  https://twitter.com/whzliam/status/51888214321...
# 45046  5.19E+017  https://twitter.com/magalhaess95/status/518882...
# 45047  5.19E+017  https://twitter.com/dressaeulalia/status/51888...
# 45048  5.19E+017  https://twitter.com/itsgabs/status/51888209665...
# 45049  5.19E+017  https://twitter.com/jonaaninhas/status/5188820...
# 45050  5.19E+017  https://twitter.com/FelipeanBh/status/51888208...
# 45051  5.19E+017  https://twitter.com/oalanferro/status/51888207...
# 45052  5.19E+017  https://twitter.com/MudaMais/status/5188820579...
# 45053  5.19E+017  https://twitter.com/Pireliss/status/5188820549...
# 45054  5.19E+017  https://twitter.com/mabyleite/status/518882039...
# 45055  5.19E+017  https://twitter.com/lucaxdamasceno/status/5188...
# 45056  5.19E+017  https://twitter.com/annaluizaC_/status/5188820...
# 45057  5.19E+017  https://twitter.com/Porra_my1/status/518882016...
# 45058  5.19E+017  https://twitter.com/Indispensavel/status/51888...
# 45059  5.19E+017  https://twitter.com/changedtome_/status/518882...
# 45060  5.19E+017  https://twitter.com/Jbiel21S/status/5188820019...
# 45061  5.19E+017  https://twitter.com/ultimosegundo/status/51888...
# 45062  5.19E+017  https://twitter.com/MathCRF_/status/5188819951...
# 45063  5.19E+017  https://twitter.com/ultimosegundo/status/51888...
# 45064  5.19E+017  https://twitter.com/ItsNiiv/status/51888197157...
# 45065  5.19E+017  https://twitter.com/marcioeliasreis/status/518...
# 45066  5.19E+017  https://twitter.com/ceesinhha/status/518881954...
#
#             score sentiment.x comment_id  sentiment.y     data sentimento
# 0       -0.100000    negativo          1          2.0  5-10-20   positivo
# 1        0.000000      neutro          3         -1.0  5-10-20   negativo
# 2       -0.300000    negativo          6          0.0  5-10-20     neutro
# 3        0.100000    positivo         10          0.0  5-10-20     neutro
# 4        0.000000      neutro         14          1.0  5-10-20   positivo
# 5       -0.700000    negativo         16         -1.0  5-10-20   negativo
# 6       -0.700000    negativo         22          1.0  5-10-20   positivo
# 7        0.433333    positivo         25          1.0  5-10-20   positivo
# 8        0.000000      neutro         30          0.0  5-10-20     neutro
# 9        0.000000      neutro         32          1.0  5-10-20   positivo
# 10      -0.500000    negativo         35         -1.0  5-10-20   negativo
# 11      -0.200000    negativo         37         -1.0  5-10-20   negativo
# 12       0.000000      neutro         40         -1.0  5-10-20   negativo
# 13       0.500000    positivo         41         -1.0  5-10-20   negativo
# 14       0.000000      neutro         47         -1.0  5-10-20   negativo
# 15       0.150000    positivo         49          0.0  5-10-20     neutro
# 16       0.370000    positivo         54          0.0  5-10-20     neutro
# 17      -0.233333    negativo         58         -1.0  5-10-20   negativo
# 18       0.550000    positivo         60         -1.0  5-10-20   negativo
# 19       0.166667    positivo         61         -1.0  5-10-20   negativo
# 20       0.000000      neutro         63          1.0  5-10-20   positivo
# 21       0.000000      neutro         64         -1.0  5-10-20   negativo
# 22       0.700000    positivo         68          0.0  5-10-20     neutro
# 23       0.000000      neutro         70          1.0  5-10-20   positivo
# 24     225.000000    positivo         74          1.0  5-10-20   positivo
# 25       0.000000      neutro         76         -3.0  5-10-20   negativo
# 26       0.250000    positivo         77         -1.0  5-10-20   negativo
# 27       0.000000      neutro         81         -1.0  5-10-20   negativo
# 28       0.000000      neutro         90          0.0  5-10-20     neutro
# 29       0.800000    positivo         92          0.0  5-10-20     neutro
# ...           ...         ...        ...          ...      ...        ...
# 45037   -0.100000    negativo     184933          1.0  5-10-20   positivo
# 45038    0.000000      neutro     184935          0.0  5-10-20     neutro
# 45039    0.000000      neutro     184941          0.0  5-10-20     neutro
# 45040    0.000000      neutro     184944         -2.0  5-10-20   negativo
# 45041    0.200000    positivo     184948          0.0  5-10-20     neutro
# 45042    0.300000    positivo     184953         -1.0  5-10-20   negativo
# 45043   -0.400000    negativo     184957         -1.0  5-10-20   negativo
# 45044    0.200000    positivo     184958         -1.0  5-10-20   negativo
# 45045    0.550000    positivo     184961          0.0  5-10-20     neutro
# 45046    0.000000      neutro     184963         -1.0  5-10-20   negativo
# 45047    0.800000    positivo     184971          0.0  5-10-20     neutro
# 45048   -0.100000    negativo     184973         -2.0  5-10-20   negativo
# 45049    0.000000      neutro     184976         -1.0  5-10-20   negativo
# 45050   -0.100000    negativo     184978          0.0  5-10-20     neutro
# 45051    0.087500    positivo     184984          0.0  5-10-20     neutro
# 45052    0.000000      neutro     184987          0.0  5-10-20     neutro
# 45053    0.258333    positivo     184988          1.0  5-10-20   positivo
# 45054    0.250000    positivo     184991          2.0  5-10-20   positivo
# 45055   -0.133333    negativo     184992         -1.0  5-10-20   negativo
# 45056    0.000000      neutro     184993         -1.0  5-10-20   negativo
# 45057    0.000000      neutro     184997          1.0  5-10-20   positivo
# 45058   -0.100000    negativo     184998          0.0  5-10-20     neutro
# 45059   -0.033333    negativo     185004         -1.0  5-10-20   negativo
# 45060    0.500000    positivo     185006          1.0  5-10-20   positivo
# 45061    0.500000    positivo     185007          1.0  5-10-20   positivo
# 45062   -0.300000    negativo     185008         -1.0  5-10-20   negativo
# 45063    0.500000    positivo     185010          1.0  5-10-20   positivo
# 45064   -0.500000    negativo     185017         -1.0  5-10-20   negativo
# 45065    0.200000    positivo     185024          0.0  5-10-20     neutro
# 45066   -0.100000    negativo     185025         -2.0  5-10-20   negativo
#
# [45067 rows x 16 columns]

# %%
vectorizer = TfidfVectorizer(use_idf=True,
                             lowercase=True, strip_accents='ascii', stop_words=None)

# %%
Y = dilma1turno['sentiment.x']

# %%
X = vectorizer.fit_transform(dilma1turno['text'])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

# %%
clf = naive_bayes.MultinomialNB()

# %%
clf.fit(X_train,Y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
tweet = np.array(['Eu odeio a Dilma'])

# %%
tweet_vector = vectorizer.transform(tweet)

# %%
print(clf.predict(tweet_vector))
# Out:
# ['negativo']

# %%
clf.score(X_train,Y_train)
# Out:
# 0.8162130177514793
